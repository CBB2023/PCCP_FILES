# %%
from google.colab import drive
drive.mount('/content/drive')
import seaborn as sns;sns.set_theme()
sns.set_color_codes()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import interp2d
import matplotlib.colors as colors

# %matplotlib inline
sns.set_style('white')
sns.set_style("ticks")
# Out:
# Mounted at /content/drive

# %%
#################################### Fig 4 ###########################################

#################################### RUE IS OPTIMIZED. Subfig 1 ###########################################

url1='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/rue_ana_heatmap1_aw_1_10_length_10.txt'
df_heatmap = pd.read_csv(url1,sep = ',', header=None)
url2='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/te_ad_rue_exp_ir_w_inayat_rate.txt'
df_wild = pd.read_csv(url2,delim_whitespace=True)
df_wild.columns= ['g_no','gene','gene_name2','te','ad','rue','exp_level','a','w']

fig, ax = plt.subplots(2,1, figsize=(10, 10), sharey=False)
texts = ['(A)', '(B)']
axes = fig.get_axes()

for a,l in zip(axes, texts):
    a.annotate(l, xy=(-0.2, 1.0), xycoords="axes fraction", fontsize=15)

alpha_rates = np.linspace(0.0,60,10000);
omega_rates = np.linspace(0.0,200,1000);
xv,yv= np.meshgrid(alpha_rates,omega_rates)
# f=df_heatmap.rue
# Z = f.values.reshape(700, 700)
beta=30;
c=(1+np.sqrt(10));
x =np.linspace(0,beta,20)
y = c*x;

ax[0].set_yscale("log")
ax[0].set_xscale("log")

im=ax[0].pcolormesh(alpha_rates,omega_rates,df_heatmap,cmap ='YlGnBu', alpha=0.5)
fig.colorbar(im)
#plt.axhline(y=beta*c, xmin = .77, xmax = 1, color="r");
#plt.axvline(x=beta, ymin = beta*c, ymax = 30, color="r");
ax[0].plot(x, y, color="k", linewidth=1.5)
ax[0].hlines(y=beta*c, xmin=beta, xmax = 60, color="k", linewidth=1.5)
ax[0].vlines(x=beta, ymin=beta*c, ymax = 200, color="k", linewidth=1.5)

# sns.scatterplot(data=df_wild, x="a", y="w", hue="rue", palette="dark:#5A9_r", ax=ax[0])
sns.scatterplot(data=df_wild, x="a", y="w", hue="exp_level", palette="dark:#5A9_r", ax=ax[0])

ax[0].set_xlabel(r'$ \mathrm{\alpha\hspace{.4}(s^{-1})} $')
ax[0].set_ylabel(r'$ \mathrm{\omega\hspace{.4}(s^{-1})} $')
ax[0].set_title('Ribosome Utilization Efficiency (RUE)')
ax[0].legend(title="Expression level")# plt.xlim(0, 1)

ax[0].legend(loc="upper left", bbox_to_anchor=(1.15, 1))


#################################### Subfig2  ###########################################

import matplotlib.pyplot as plt
import numpy as np

url1='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/te_ana_heatmap1_aw_1_10_length_10.txt'
df_heatmap = pd.read_csv(url1,sep = ',', header=None)

# url2='/content/drive/MyDrive/Colab Notebooks/heatmaps/colab_exp_level_ir.txt'
# df_wild = pd.read_csv(url2,delim_whitespace=True)
# df_wild.columns= ['g_no','gene','te','ad','rue','a','w','exp_level']
# alpha_rates = np.linspace(0.0,60,5000);
# omega_rates = np.linspace(0.0,200,5000);
# xv,yv= np.meshgrid(alpha_rates,omega_rates)

beta=30;
c=(1+np.sqrt(10));
x =np.linspace(0,beta,20)
y = c*x;
ax[1].set_yscale("log")
ax[1].set_xscale("log")
im=ax[1].pcolormesh(alpha_rates,omega_rates,df_heatmap,cmap ='YlGnBu', alpha=0.5)
fig.colorbar(im)
ax[1].plot(x, y, color="k", linewidth=1.5)
ax[1].hlines(y=beta*c, xmin=beta, xmax = 60, color="k", linewidth=1.5)
ax[1].vlines(x=beta, ymin=beta*c, ymax = 200, color="k", linewidth=1.5)
# sns.scatterplot(data=df_wild, x="a", y="w", hue="te",color='red', palette="flare",ax=ax[1])
# cmap = plt.get_cmap('Accent')
# sns.scatterplot(data=df_wild, x="a", y="w", hue="exp_level", palette="dark:#5A9_r", c=df_wild["exp_level"], cmap=cmap, ax=ax[1], vmin=000, vmax=100)
sns.scatterplot(data=df_wild, x="a", y="w", hue="exp_level", palette="dark:#5A9_r",ax=ax[1])

ax[1].set_xlabel(r'$ \mathrm{\alpha\hspace{.4}(s^{-1})} $')
ax[1].set_ylabel(r'$ \mathrm{\omega\hspace{.4}(s^{-1})} $')
ax[1].set_title('Flux (J)')
ax[1].legend(title="Expression level")# plt.xlim(0, 1)
ax[1].legend(loc="upper left", bbox_to_anchor=(1.15, 1))   # moves legend out of plot to some position
fig.subplots_adjust(hspace=0.3)   #  Adjust the spacing between subplots
plt.show()
fig.savefig("FIG_4.jpg", transparent=True, bbox_inches='tight', pad_inches=0,dpi=1000 )

from google.colab import files

files.download('/content/FIG_4.jpg')
#,norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03,vmin=0, vmax=100.0, base=10)

# %%
#################################### Fig 4 ###########################################

#################################### RUE IS OPTIMIZED. Subfig 1 ###########################################

url1='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/rue_ana_heatmap1_aw_final_length_10.txt'
df_heatmap = pd.read_csv(url1,sep = ',', header=None)
url2='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/te_ad_rue_exp_ir_w.txt'
df_wild = pd.read_csv(url2,delim_whitespace=True)
df_wild.columns= ['g_no','gene','gene_name2','te','ad','rue','exp_level','a','w']

fig, ax = plt.subplots(2,1, figsize=(10, 10), sharey=False)
texts = ['(A)', '(B)']
axes = fig.get_axes()

for a,l in zip(axes, texts):
    a.annotate(l, xy=(-0.2, 1.0), xycoords="axes fraction", fontsize=15)

alpha_rates = np.linspace(0.0,60,10000);
omega_rates = np.linspace(0.0,200,1000);
xv,yv= np.meshgrid(alpha_rates,omega_rates)
# f=df_heatmap.rue
# Z = f.values.reshape(700, 700)
beta=30;
c=(1+np.sqrt(10));
x =np.linspace(0,beta,20)
y = c*x;

ax[0].set_yscale("log")
ax[0].set_xscale("log")

im=ax[0].pcolormesh(alpha_rates,omega_rates,df_heatmap,cmap ='YlGnBu', alpha=0.5)
fig.colorbar(im)
#plt.axhline(y=beta*c, xmin = .77, xmax = 1, color="r");
#plt.axvline(x=beta, ymin = beta*c, ymax = 30, color="r");
ax[0].plot(x, y, color="k", linewidth=1.5)
ax[0].hlines(y=beta*c, xmin=beta, xmax = 60, color="k", linewidth=1.5)
ax[0].vlines(x=beta, ymin=beta*c, ymax = 200, color="k", linewidth=1.5)
# sns.scatterplot(data=df_wild, x="a", y="w", hue="rue", palette="dark:#5A9_r", ax=ax[0])
sns.scatterplot(data=df_wild, x="a", y="w", hue="exp_level", palette="dark:#5A9_r", ax=ax[0])

ax[0].set_xlabel(r'$ \mathrm{\alpha\hspace{.4}(s^{-1})} $')
ax[0].set_ylabel(r'$ \mathrm{\omega\hspace{.4}(s^{-1})} $')
ax[0].set_title('Ribosome Utilization Efficiency (RUE)')

ax[0].legend(title="Expression level", loc="upper left", bbox_to_anchor=(1.15, 1))


#################################### Subfig2  ###########################################

import matplotlib.pyplot as plt
import numpy as np

url1='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/te_ana_heatmap1_aw_final_length_10.txt'
df_heatmap = pd.read_csv(url1,sep = ',', header=None)

# url2='/content/drive/MyDrive/Colab Notebooks/heatmaps/colab_exp_level_ir.txt'
# df_wild = pd.read_csv(url2,delim_whitespace=True)
# df_wild.columns= ['g_no','gene','te','ad','rue','a','w','exp_level']
# alpha_rates = np.linspace(0.0,60,5000);
# omega_rates = np.linspace(0.0,200,5000);
# xv,yv= np.meshgrid(alpha_rates,omega_rates)

beta=30;
c=(1+np.sqrt(10));
x =np.linspace(0,beta,20)
y = c*x;
ax[1].set_yscale("log")
ax[1].set_xscale("log")
im=ax[1].pcolormesh(alpha_rates,omega_rates,df_heatmap,cmap ='YlGnBu', alpha=0.5)
fig.colorbar(im)
ax[1].plot(x, y, color="k", linewidth=1.5)
ax[1].hlines(y=beta*c, xmin=beta,xmax = 60, color="k", linewidth=1.5)
ax[1].vlines(x=beta, ymin=beta*c, ymax = 200, color="k", linewidth=1.5)
# sns.scatterplot(data=df_wild, x="a", y="w", hue="te",color='red', palette="flare",ax=ax[1])
# cmap = plt.get_cmap('Accent')
# sns.scatterplot(data=df_wild, x="a", y="w", hue="exp_level", palette="dark:#5A9_r", c=df_wild["exp_level"], cmap=cmap, ax=ax[1], vmin=000, vmax=100)
sns.scatterplot(data=df_wild, x="a", y="w", hue="exp_level", palette="dark:#5A9_r",ax=ax[1])

ax[1].set_xlabel(r'$ \mathrm{\alpha\hspace{.4}(s^{-1})} $')
ax[1].set_ylabel(r'$ \mathrm{\omega\hspace{.4}(s^{-1})} $')
ax[1].set_title('Flux (J)')

ax[1].legend(title="Expression level",loc="upper left", bbox_to_anchor=(1.15, 1))   # moves legend out of plot to some position
fig.subplots_adjust(hspace=0.3)   #  Adjust the spacing between subplots
plt.show()


# fig.savefig("FIG_4.jpg", transparent=True, bbox_inches='tight', pad_inches=0,dpi=1000 )

# from google.colab import files

# files.download('/content/FIG_4.jpg')
# Out:
# <ipython-input-5-149e7dc4856e>:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_wild = pd.read_csv(url2,delim_whitespace=True)

# %%
#################################### Fig 4 ###########################################

#################################### RUE IS OPTIMIZED. Subfig 1 ###########################################

url1='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/rue_ana_heatmap1_aw_final_length_10.txt'
df_heatmap = pd.read_csv(url1,sep = ',', header=None)
url2='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/te_ad_rue_exp_ir_w.txt'
df_wild = pd.read_csv(url2,delim_whitespace=True)
df_wild.columns= ['g_no','gene','gene_name2','te','ad','rue','exp_level','a','w']

fig, ax = plt.subplots(2,1, figsize=(10, 10), sharey=False)
texts = ['(A)', '(B)']
axes = fig.get_axes()

for a,l in zip(axes, texts):
    a.annotate(l, xy=(-0.2, 1.0), xycoords="axes fraction", fontsize=15)

alpha_rates = np.linspace(0.0,60,10000);
omega_rates = np.linspace(0.0,200,1000);
xv,yv= np.meshgrid(alpha_rates,omega_rates)
# f=df_heatmap.rue
# Z = f.values.reshape(700, 700)
beta=30;
c=(1+np.sqrt(10));
x =np.linspace(0,beta,20)
y = c*x;

ax[0].set_yscale("log")
ax[0].set_xscale("log")

im=ax[0].pcolormesh(alpha_rates,omega_rates,df_heatmap,cmap ='YlGnBu', alpha=0.5, vmin=0, vmax=10)
fig.colorbar(im)
#plt.axhline(y=beta*c, xmin = .77, xmax = 1, color="r");
#plt.axvline(x=beta, ymin = beta*c, ymax = 30, color="r");
ax[0].plot(x, y, color="k", linewidth=1.5)
ax[0].hlines(y=beta*c, xmin=beta, xmax = 60, color="k", linewidth=1.5)
ax[0].vlines(x=beta, ymin=beta*c, ymax = 200, color="k", linewidth=1.5)
# sns.scatterplot(data=df_wild, x="a", y="w", hue="rue", palette="dark:#5A9_r", ax=ax[0])
sns.scatterplot(data=df_wild, x="a", y="w", hue="exp_level", palette="dark:#5A9_r", ax=ax[0])

ax[0].set_xlabel(r'$ \mathrm{\alpha\hspace{.4}(s^{-1})} $')
ax[0].set_ylabel(r'$ \mathrm{\omega\hspace{.4}(s^{-1})} $')
ax[0].set_title('Ribosome Utilization Efficiency (RUE)')

ax[0].legend(title="Expression level", loc="upper left", bbox_to_anchor=(1.15, 1))


#################################### Subfig2  ###########################################

import matplotlib.pyplot as plt
import numpy as np

url1='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/te_ana_heatmap1_aw_final_length_10.txt'
df_heatmap = pd.read_csv(url1,sep = ',', header=None)

# url2='/content/drive/MyDrive/Colab Notebooks/heatmaps/colab_exp_level_ir.txt'
# df_wild = pd.read_csv(url2,delim_whitespace=True)
# df_wild.columns= ['g_no','gene','te','ad','rue','a','w','exp_level']
# alpha_rates = np.linspace(0.0,60,5000);
# omega_rates = np.linspace(0.0,200,5000);
# xv,yv= np.meshgrid(alpha_rates,omega_rates)

beta=30;
c=(1+np.sqrt(10));
x =np.linspace(0,beta,20)
y = c*x;
ax[1].set_yscale("log")
ax[1].set_xscale("log")
im=ax[1].pcolormesh(alpha_rates,omega_rates,df_heatmap,cmap ='YlGnBu', alpha=0.5, vmin=0, vmax=1)
fig.colorbar(im)
ax[1].plot(x, y, color="k", linewidth=1.5)
ax[1].hlines(y=beta*c, xmin=beta,xmax = 60, color="k", linewidth=1.5)
ax[1].vlines(x=beta, ymin=beta*c, ymax = 200, color="k", linewidth=1.5)
# sns.scatterplot(data=df_wild, x="a", y="w", hue="te",color='red', palette="flare",ax=ax[1])
# cmap = plt.get_cmap('Accent')
# sns.scatterplot(data=df_wild, x="a", y="w", hue="exp_level", palette="dark:#5A9_r", c=df_wild["exp_level"], cmap=cmap, ax=ax[1], vmin=000, vmax=100)
sns.scatterplot(data=df_wild, x="a", y="w", hue="exp_level", palette="dark:#5A9_r",ax=ax[1])

ax[1].set_xlabel(r'$ \mathrm{\alpha\hspace{.4}(s^{-1})} $')
ax[1].set_ylabel(r'$ \mathrm{\omega\hspace{.4}(s^{-1})} $')
ax[1].set_title('Flux (J)')

ax[1].legend(title="Expression level",loc="upper left", bbox_to_anchor=(1.15, 1))   # moves legend out of plot to some position
fig.subplots_adjust(hspace=0.3)   #  Adjust the spacing between subplots
plt.show()


fig.savefig("FIG_4.jpg", transparent=True, bbox_inches='tight', pad_inches=0,dpi=1000 )

from google.colab import files

files.download('/content/FIG_4.jpg')
# Out:
# <ipython-input-14-97172297fb5a>:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_wild = pd.read_csv(url2,delim_whitespace=True)

# %%
#################################### Fig 4  official ###########################################

#################################### RUE IS OPTIMIZED. Subfig 1 ###########################################

url1='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/rue_ana_heatmap1_aw_final_length_10.txt'
df_heatmap = pd.read_csv(url1,sep = ',', header=None)
url2='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/te_ad_rue_exp_ir_w.txt'
df_wild = pd.read_csv(url2,delim_whitespace=True)
df_wild.columns= ['g_no','gene','gene_name2','te','ad','rue','exp_level','a','w']
url3='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/rue_ana_heatmap1_aw_final_subset_length_10.txt'
df_subset_heatmap = pd.read_csv(url3,sep = ',', header=None)


fig, ax = plt.subplots(2,1, figsize=(10, 10), sharey=False)
texts = ['(A)', '(B)']
axes = fig.get_axes()

for a,l in zip(axes, texts):
    a.annotate(l, xy=(-0.2, 1.0), xycoords="axes fraction", fontsize=15)

alpha_rates = np.linspace(0.0,60,10000);
omega_rates = np.linspace(0.0,200,1000);
alpha_rates1 = np.linspace(0.05,10,10000);
omega_rates1 = np.linspace(5,15,1000);
xv,yv= np.meshgrid(alpha_rates,omega_rates)
# f=df_heatmap.rue
# Z = f.values.reshape(700, 700)
beta=30;
c=(1+np.sqrt(10));
x =np.linspace(0,beta,20)
y = c*x;

ax[0].set_yscale("log")
ax[0].set_xscale("log")

im=ax[0].pcolormesh(alpha_rates,omega_rates,df_heatmap,cmap ='YlGnBu', alpha=0.5)
fig.colorbar(im)
#plt.axhline(y=beta*c, xmin = .77, xmax = 1, color="r");
#plt.axvline(x=beta, ymin = beta*c, ymax = 30, color="r");
ax[0].plot(x, y, color="k", linewidth=1.5)
ax[0].hlines(y=beta*c, xmin=beta, xmax = 60, color="k", linewidth=1.5)
ax[0].vlines(x=beta, ymin=beta*c, ymax = 200, color="k", linewidth=1.5)
# sns.scatterplot(data=df_wild, x="a", y="w", hue="rue", palette="dark:#5A9_r", ax=ax[0])
sns.scatterplot(data=df_wild, x="a", y="w", hue="exp_level", palette="dark:#5A9_r", ax=ax[0])

ax[0].set_xlabel(r'$ \mathrm{\alpha\hspace{.4}(s^{-1})} $')
ax[0].set_ylabel(r'$ \mathrm{\omega\hspace{.4}(s^{-1})} $')
ax[0].set_title('Ribosome Utilization Efficiency (RUE)')

ax[0].legend(title="Expression level", loc="upper left", bbox_to_anchor=(1.52, 0.39))

# Create an inset axis
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset



# Create the inset axis
# axins=inset_axes(ax[0], width="40%", height="40%", loc="upper left")
inset_pos = [1.3, 0.4, 0.6, 0.6]  # [x, y, width, height]
axins = inset_axes(ax[0], width="70%", height="70%", loc='upper left', bbox_to_anchor=inset_pos, bbox_transform=ax[0].transAxes)

# Plot the zoomed-in region in the inset axis
axins.pcolormesh(alpha_rates1,omega_rates1,df_subset_heatmap,cmap ='YlGnBu', alpha=0.5)
cbaxes = inset_axes(axins, width="5%", height="100%", loc='upper right', bbox_to_anchor=(0.15, 0.036, 1, 1), bbox_transform=axins.transAxes)
cbar = plt.colorbar(axins.collections[0], cax=cbaxes, format="%.1f")
sns.scatterplot(data=df_wild,  x="a", y="w", hue='exp_level', palette='dark:#5A9_r', ax=axins, legend=False)
x1, x2, y1, y2 = 0.05, 10, 5.6, 15

axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
# axins.set_yticklabels(['10'])

axins.set_yscale("log")
axins.set_xscale("log")
# axins.set_yticks([1,10])

# axins.set_xticklabels('')
# axins.set_yticklabels('')
axins.set_xlabel(None)
axins.set_ylabel(None)
axins.plot(x, y, color="k", linewidth=1.5)
axins.hlines(y=beta*c, xmin=beta, xmax = 10, color="k", linewidth=1.5)
axins.vlines(x=beta, ymin=beta*c, ymax = 15, color="k", linewidth=1.5)
# ax[0].indicate_inset_zoom(axins)
mark_inset(ax[0], axins, loc1=2, loc2=4, fc="none", ec="0.5",edgecolor="black")


#################################### Subfig2  ###########################################

import matplotlib.pyplot as plt
import numpy as np

url1='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/te_ana_heatmap1_aw_final_length_10.txt'
df_heatmap = pd.read_csv(url1,sep = ',', header=None)

url2='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/te_ana_heatmap1_aw_final_subset_length_10.txt'
df_subset_heatmap = pd.read_csv(url2,sep = ',', header=None)

beta=30;
c=(1+np.sqrt(10));
x =np.linspace(0,beta,20)
y = c*x;
ax[1].set_yscale("log")
ax[1].set_xscale("log")
im=ax[1].pcolormesh(alpha_rates,omega_rates,df_heatmap,cmap ='YlGnBu', alpha=0.5)
fig.colorbar(im)
ax[1].plot(x, y, color="k", linewidth=1.5)
ax[1].hlines(y=beta*c, xmin=beta, xmax = 60, color="k", linewidth=1.5)
ax[1].vlines(x=beta, ymin=beta*c, ymax = 200, color="k", linewidth=1.5)

sns.scatterplot(data=df_wild, x="a", y="w", hue="exp_level", palette="dark:#5A9_r",ax=ax[1])

ax[1].set_xlabel(r'$ \mathrm{\alpha\hspace{.4}(s^{-1})} $')
ax[1].set_ylabel(r'$ \mathrm{\omega\hspace{.4}(s^{-1})} $')
ax[1].set_title('Flux (J)')
ax[1].legend(title="Expression level", loc="upper left", bbox_to_anchor=(1.52, 0.39))   # moves legend out of plot to some position
fig.subplots_adjust(hspace=0.3)   #  Adjust the spacing between subplots

# Create an inset axis
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset

# # Define the extent for the image (x-axis min, x-axis max, y-axis min, y-axis max)
# extent = (0, 60, 0, 200)

# loc=[0.5 0.5, 0.47, 0.47]"upper right"width="40%", height="40%",

# Create the inset axis

#axins1=inset_axes(ax[1], width="40%", height="40%", loc="upper left")
inset_pos = [1.3, 0.4, 0.6, 0.6]  # [x, y, width, height]
# axins1=inset_axes(ax[1], width="40%", height="40%", bbox_to_anchor=inset_pos)
axins1 = inset_axes(ax[1], width="70%", height="70%", loc='upper left', bbox_to_anchor=inset_pos, bbox_transform=ax[1].transAxes)

# axins = inset_axes(ax[1],  width="10%", height="10%", bbox_to_anchor=(1,0.2, 0.47, 0.17), bbox_transform=ax[1].transAxes)


# Plot the zoomed-in region in the inset axis
axins1.set_yscale("log")
axins1.set_xscale("log")
axins1.pcolormesh(alpha_rates1, omega_rates1, df_subset_heatmap, cmap ='YlGnBu', alpha=0.5)
cbaxes = inset_axes(axins1, width="5%", height="100%", loc='upper right', bbox_to_anchor=(0.15, 0.036, 1 ,1), bbox_transform=axins1.transAxes) # width,height% of colorbar,bbox=(x,y,width,height)
cbar = plt.colorbar(axins1.collections[0], cax=cbaxes, format="%.1f")

sns.scatterplot(data=df_wild,  x="a", y="w", hue='exp_level', palette='dark:#5A9_r', ax=axins1, legend=False)

# axins1.set_xticklabels(['0.1', '1', '10'])

x1, x2, y1, y2 = 0.05, 10, 5.6, 15

axins1.set_xlim(x1, x2)
axins1.set_ylim(y1, y2)
# axins1.set_yticklabels([10])
# axins1.set_yticks([10])
axins1.set_xlabel(None)
axins1.set_ylabel(None)
axins1.plot(x, y, color="k", linewidth=1.5)
axins1.hlines(y=beta*c, xmin=beta, xmax = 10, color="k", linewidth=1.5)
axins1.vlines(x=beta, ymin=beta*c, ymax = 15, color="k", linewidth=1.5)
#  Add the lines to indicate where the inset axis is coming from

mark_inset(ax[1], axins1, loc1=2, loc2=4, fc="none", ec="0.5", edgecolor="black")

# # axis.indicate_inset_zoom(axin)
# ax[1].indicate_inset_zoom(axins)

plt.show()

fig.savefig("FIG_4.jpg", transparent=True, bbox_inches='tight', pad_inches=0,dpi=1000 )

from google.colab import files

files.download('/content/FIG_4.jpg')

# %%
#################################### Fig 4 ###########################################

#################################### RUE IS OPTIMIZED. Subfig 1 ###########################################
from google.colab import drive
drive.mount('/content/drive')
import seaborn as sns;sns.set_theme()
sns.set_color_codes()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import interp2d
import matplotlib.colors as colors

# %matplotlib inline
sns.set_style('white')
sns.set_style("ticks")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import LogNorm
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset

# Read data
url1 = '/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/rue_ana_heatmap1_aw_final_length_10.txt'
df_heatmap = pd.read_csv(url1, sep=',', header=None)

url2 = '/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/te_ad_rue_exp_ir_w.txt'
df_wild = pd.read_csv(url2, delim_whitespace=True)
df_wild.columns = ['g_no', 'gene', 'gene_name2', 'te', 'ad', 'rue', 'exp_level', 'a', 'w']

url3 = '/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/rue_ana_heatmap1_aw_final_subset_length_10.txt'
df_subset_heatmap = pd.read_csv(url3, sep=',', header=None)

# Prepare alpha and omega rates
alpha_rates = np.linspace(0.0, 60, 10000)
omega_rates = np.linspace(0.0, 200, 1000)
alpha_rates1 = np.linspace(0.05, 10, 10000)
omega_rates1 = np.linspace(5, 15, 1000)

# Log scale for data - replace non-positive values with NaN to handle logarithmic scale issues
df_heatmap_logged = df_heatmap.copy()
df_subset_heatmap_logged = df_subset_heatmap.copy()

df_heatmap_logged[df_heatmap_logged <= 0] = np.nan
df_subset_heatmap_logged[df_subset_heatmap_logged <= 0] = np.nan

# Plot setup
fig, ax = plt.subplots(2, 1, figsize=(10, 10), sharey=False)
texts = ['(A)', '(B)']
axes = fig.get_axes()

for a, l in zip(axes, texts):
    a.annotate(l, xy=(-0.2, 1.0), xycoords="axes fraction", fontsize=15)

beta = 30
c = (1 + np.sqrt(10))
x = np.linspace(0, beta, 20)
y = c * x

# First subplot: RUE Heatmap
ax[0].set_yscale("log")
ax[0].set_xscale("log")

im = ax[0].pcolormesh(alpha_rates, omega_rates, df_heatmap_logged, cmap='YlGnBu', alpha=0.5)
fig.colorbar(im, ax=ax[0])

ax[0].plot(x, y, color="k", linewidth=1.5)
ax[0].hlines(y=beta * c, xmin=beta, xmax=60, color="k", linewidth=1.5)
ax[0].vlines(x=beta, ymin=beta * c, ymax=200, color="k", linewidth=1.5)

sns.scatterplot(data=df_wild, x="a", y="w", hue="exp_level", palette="dark:#5A9_r", ax=ax[0])

ax[0].set_xlabel(r'$ \mathrm{\alpha\hspace{.4}(s^{-1})} $')
ax[0].set_ylabel(r'$ \mathrm{\omega\hspace{.4}(s^{-1})} $')
ax[0].set_title('Ribosome Utilization Efficiency (RUE)')
ax[0].legend(title="Expression level", loc="upper left", bbox_to_anchor=(1.52, 0.39))

# Inset plot for first subplot
inset_pos = [1.3, 0.4, 0.6, 0.6]  # [x, y, width, height]
axins = inset_axes(ax[0], width="70%", height="70%", loc='upper left', bbox_to_anchor=inset_pos, bbox_transform=ax[0].transAxes)

axins.pcolormesh(alpha_rates1, omega_rates1, df_subset_heatmap_logged, cmap='YlGnBu', alpha=0.5)
cbaxes = inset_axes(axins, width="5%", height="100%", loc='upper right', bbox_to_anchor=(0.15, 0.036, 1, 1), bbox_transform=axins.transAxes)
cbar = plt.colorbar(axins.collections[0], cax=cbaxes, format="%.1f")

sns.scatterplot(data=df_wild, x="a", y="w", hue='exp_level', palette='dark:#5A9_r', ax=axins, legend=False)

x1, x2, y1, y2 = 0.05, 10, 5.6, 15
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
axins.set_yscale("log")
axins.set_xscale("log")
axins.plot(x, y, color="k", linewidth=1.5)
axins.hlines(y=beta * c, xmin=beta, xmax=10, color="k", linewidth=1.5)
axins.vlines(x=beta, ymin=beta * c, ymax=15, color="k", linewidth=1.5)
mark_inset(ax[0], axins, loc1=2, loc2=4, fc="none", ec="0.5", edgecolor="black")

# Second subplot: Flux Heatmap
url1 = '/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/te_ana_heatmap1_aw_final_length_10.txt'
df_heatmap = pd.read_csv(url1, sep=',', header=None)

url2 = '/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/te_ana_heatmap1_aw_final_subset_length_10.txt'
df_subset_heatmap = pd.read_csv(url2, sep=',', header=None)

df_heatmap_logged = df_heatmap.copy()
df_subset_heatmap_logged = df_subset_heatmap.copy()

df_heatmap_logged[df_heatmap_logged <= 0] = np.nan
df_subset_heatmap_logged[df_subset_heatmap_logged <= 0] = np.nan

ax[1].set_yscale("log")
ax[1].set_xscale("log")

im = ax[1].pcolormesh(alpha_rates, omega_rates, df_heatmap_logged, cmap='YlGnBu', alpha=0.5)
fig.colorbar(im, ax=ax[1])

ax[1].plot(x, y, color="k", linewidth=1.5)
ax[1].hlines(y=beta * c, xmin=beta, xmax=60, color="k", linewidth=1.5)
ax[1].vlines(x=beta, ymin=beta * c, ymax=200, color="k", linewidth=1.5)

sns.scatterplot(data=df_wild, x="a", y="w", hue="exp_level", palette="dark:#5A9_r", ax=ax[1])

ax[1].set_xlabel(r'$ \mathrm{\alpha\hspace{.4}(s^{-1})} $')
ax[1].set_ylabel(r'$ \mathrm{\omega\hspace{.4}(s^{-1})} $')
ax[1].set_title('Flux (J)')
ax[1].legend(title="Expression level", loc="upper left", bbox_to_anchor=(1.52, 0.39))

# Inset plot for second subplot
axins1 = inset_axes(ax[1], width="70%", height="70%", loc='upper left', bbox_to_anchor=inset_pos, bbox_transform=ax[1].transAxes)

axins1.pcolormesh(alpha_rates1, omega_rates1, df_subset_heatmap_logged, cmap='YlGnBu', alpha=0.5, norm=LogNorm())
cbaxes = inset_axes(axins1, width="5%", height="100%", loc='upper right', bbox_to_anchor=(0.15, 0.036, 1, 1), bbox_transform=axins1.transAxes)
cbar = plt.colorbar(axins1.collections[0], cax=cbaxes, format="%.1f")

sns.scatterplot(data=df_wild, x="a", y="w", hue='exp_level', palette='dark:#5A9_r', ax=axins1, legend=False)

axins1.set_xlim(x1, x2)
axins1.set_ylim(y1, y2)
axins1.set_yscale("log")
axins1.set_xscale("log")
axins1.plot(x, y, color="k", linewidth=1.5)
axins1.hlines(y=beta * c, xmin=beta, xmax=10, color="k", linewidth=1.5)
axins1.vlines(x=beta, ymin=beta * c, ymax=15, color="k", linewidth=1.5)
mark_inset(ax[1], axins1, loc1=2, loc2=4, fc="none", ec="0.5", edgecolor="black")
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
import seaborn as sns;sns.set_theme()
sns.set_color_codes()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import interp2d
import matplotlib.colors as colors

# %matplotlib inline
sns.set_style('white')
sns.set_style("ticks")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np


# url2 = '/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/te_ad_rue_exp_ir_w.txt'
# df_wild = pd.read_csv(url2, delim_whitespace=True)
# Load the ribosome-profiling-derived rate data
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/te_ad_rue_exp_ir_w.txt', delim_whitespace=True)
# columns: gene_no, gene, g_name2, flux, ad, rue, exp_level, ir, avg_omega
# ir        = alpha, the inferred initiation rate (s^-1)
# avg_omega = omega, the gene-averaged elongation rate (s^-1)

alpha = df['ir']
omega = df['avg_omega']

# LD-MC phase boundary: omega = c * alpha
c = 1 + np.sqrt(10)   # ~4.1623

# For each gene, the alpha value that would put it exactly on the boundary
# (holding its own omega fixed)
alpha_boundary = omega / c

# Per-gene fold-margin: how many-fold alpha would need to increase to reach
# the boundary at that gene's own omega. >1 means the gene is inside LD.
fold_margin = alpha_boundary / alpha

# --- Y: population-level margin (median gene) ---
Y_median_of_ratios = fold_margin.median()

# sanity check: ratio of medians instead of median of ratios
Y_ratio_of_medians = (omega.median() / c) / alpha.median()

# --- Z: margin for the single closest gene ---
idx_closest = fold_margin.idxmin()
Z = fold_margin.min()
closest_gene = df.loc[idx_closest, ['gene', 'g_name2', 'ir', 'avg_omega']]

print(f"c (LD-MC boundary slope)     : {c:.6f}")
print(f"median alpha (ir)            : {alpha.median():.6f} s^-1")
print(f"median omega (avg_omega)     : {omega.median():.6f} s^-1")
print(f"Y (median of per-gene folds) : {Y_median_of_ratios:.4f}")
print(f"Y (ratio of medians, check)  : {Y_ratio_of_medians:.4f}")
print(f"Z (min fold, closest gene)   : {Z:.4f}")
print(f"Closest gene details:\n{closest_gene}")
# Out:
# /tmp/ipykernel_2440/1293223193.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/te_ad_rue_exp_ir_w.txt', delim_whitespace=True)
# c (LD-MC boundary slope)     : 4.162278
# median alpha (ir)            : 0.139729 s^-1
# median omega (avg_omega)     : 10.921925 s^-1
# Y (median of per-gene folds) : 18.8619
# Y (ratio of medians, check)  : 18.7794
# Z (min fold, closest gene)   : 1.5905
# Closest gene details:
# gene            b4108
# g_name2          yjdM
# ir           1.824769
# avg_omega    12.08016
# Name: 1497, dtype: object

# %%
#################################### Fig 4 ###########################################

#################################### RUE IS OPTIMIZED. Subfig 1 ###########################################

url1='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/rue_ana_heatmap1_aw_final_length_10.txt'
df_heatmap = pd.read_csv(url1,sep = ',', header=None)
url2='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/te_ad_rue_exp_ir_w.txt'
df_wild = pd.read_csv(url2,delim_whitespace=True)
df_wild.columns= ['g_no','gene','gene_name2','te','ad','rue','exp_level','a','w']
url3='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/rue_ana_heatmap1_aw_final_subset_length_10.txt'
df_subset_heatmap = pd.read_csv(url3,sep = ',', header=None)


# Replace zeros with NaN
df_heatmap[df_heatmap == 0] = np.nan
df_subset_heatmap[df_subset_heatmap == 0] = np.nan

# Apply logarithmic transformation to non-zero values
df_heatmap_log = np.log(df_heatmap)
df_subset_heatmap_log = np.log(df_subset_heatmap)

fig, ax = plt.subplots(2,1, figsize=(10, 10), sharey=False)
texts = ['(A)', '(B)']
axes = fig.get_axes()

for a,l in zip(axes, texts):
    a.annotate(l, xy=(-0.2, 1.0), xycoords="axes fraction", fontsize=15)

alpha_rates = np.linspace(0.0,60,10000);
omega_rates = np.linspace(0.0,200,1000);
alpha_rates1 = np.linspace(0.05,10,10000);
omega_rates1 = np.linspace(5,15,1000);
xv,yv= np.meshgrid(alpha_rates,omega_rates)
beta=30;
c=(1+np.sqrt(10));
x =np.linspace(0,beta,20)
y = c*x;

ax[0].set_yscale("log")
ax[0].set_xscale("log")

im=ax[0].pcolormesh(alpha_rates,omega_rates,df_heatmap_log,cmap ='YlGnBu', alpha=0.5)
fig.colorbar(im)
ax[0].plot(x, y, color="k", linewidth=1.5)
ax[0].hlines(y=beta*c, xmin=beta, xmax = 60, color="k", linewidth=1.5)
ax[0].vlines(x=beta, ymin=beta*c, ymax = 200, color="k", linewidth=1.5)
sns.scatterplot(data=df_wild, x="a", y="w", hue="exp_level", palette="dark:#5A9_r", ax=ax[0])

ax[0].set_xlabel(r'$ \mathrm{\alpha\hspace{.4}(s^{-1})} $')
ax[0].set_ylabel(r'$ \mathrm{\omega\hspace{.4}(s^{-1})} $')
ax[0].set_title('Ribosome Utilization Efficiency (RUE)')

ax[0].legend(title="Expression level", loc="upper left", bbox_to_anchor=(1.52, 0.39))

# Create an inset axis
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset



# Create the inset axis
inset_pos = [1.3, 0.4, 0.6, 0.6]  # [x, y, width, height]
axins = inset_axes(ax[0], width="70%", height="70%", loc='upper left', bbox_to_anchor=inset_pos, bbox_transform=ax[0].transAxes)

# Plot the zoomed-in region in the inset axis
axins.pcolormesh(alpha_rates1,omega_rates1,df_subset_heatmap_log,cmap ='YlGnBu', alpha=0.5)
cbaxes = inset_axes(axins, width="5%", height="100%", loc='upper right', bbox_to_anchor=(0.15, 0.036, 1, 1), bbox_transform=axins.transAxes)
cbar = plt.colorbar(axins.collections[0], cax=cbaxes, format="%.1f")
sns.scatterplot(data=df_wild,  x="a", y="w", hue='exp_level', palette='dark:#5A9_r', ax=axins, legend=False)
x1, x2, y1, y2 = 0.05, 10, 5.6, 15

axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
axins.set_yscale("log")
axins.set_xscale("log")
axins.set_xlabel(None)
axins.set_ylabel(None)
axins.plot(x, y, color="k", linewidth=1.5)
axins.hlines(y=beta*c, xmin=beta, xmax = 10, color="k", linewidth=1.5)
axins.vlines(x=beta, ymin=beta*c, ymax = 15, color="k", linewidth=1.5)
# ax[0].indicate_inset_zoom(axins)
mark_inset(ax[0], axins, loc1=2, loc2=4, fc="none", ec="0.5",edgecolor="black")


#################################### Subfig2  ###########################################

import matplotlib.pyplot as plt
import numpy as np

url1='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/te_ana_heatmap1_aw_final_length_10.txt'
df_heatmap = pd.read_csv(url1,sep = ',', header=None)

url2='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/te_ana_heatmap1_aw_final_subset_length_10.txt'
df_subset_heatmap = pd.read_csv(url2,sep = ',', header=None)

# Replace zeros with NaN
df_heatmap[df_heatmap == 0] = np.nan
df_subset_heatmap[df_subset_heatmap == 0] = np.nan

# Apply logarithmic transformation to non-zero values
df_heatmap_log = np.log(df_heatmap)
df_subset_heatmap_log = np.log(df_subset_heatmap)

beta=30;
c=(1+np.sqrt(10));
x =np.linspace(0,beta,20)
y = c*x;
ax[1].set_yscale("log")
ax[1].set_xscale("log")
im=ax[1].pcolormesh(alpha_rates,omega_rates,df_heatmap_log,cmap ='YlGnBu', alpha=0.5)
fig.colorbar(im)
ax[1].plot(x, y, color="k", linewidth=1.5)
ax[1].hlines(y=beta*c, xmin=beta, xmax = 60, color="k", linewidth=1.5)
ax[1].vlines(x=beta, ymin=beta*c, ymax = 200, color="k", linewidth=1.5)

sns.scatterplot(data=df_wild, x="a", y="w", hue="exp_level", palette="dark:#5A9_r",ax=ax[1])

ax[1].set_xlabel(r'$ \mathrm{\alpha\hspace{.4}(s^{-1})} $')
ax[1].set_ylabel(r'$ \mathrm{\omega\hspace{.4}(s^{-1})} $')
ax[1].set_title('Flux (J)')
ax[1].legend(title="Expression level", loc="upper left", bbox_to_anchor=(1.52, 0.39))   # moves legend out of plot to some position
fig.subplots_adjust(hspace=0.3)   #  Adjust the spacing between subplots

# Create an inset axis
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset
axins1 = inset_axes(ax[1], width="70%", height="70%", loc='upper left', bbox_to_anchor=inset_pos, bbox_transform=ax[1].transAxes)


# Plot the zoomed-in region in the inset axis
axins1.set_yscale("log")
axins1.set_xscale("log")
axins1.pcolormesh(alpha_rates1, omega_rates1, df_subset_heatmap_log, cmap ='YlGnBu', alpha=0.5)
cbaxes = inset_axes(axins1, width="5%", height="100%", loc='upper right', bbox_to_anchor=(0.15, 0.036, 1 ,1), bbox_transform=axins1.transAxes) # width,height% of colorbar,bbox=(x,y,width,height)
cbar = plt.colorbar(axins1.collections[0], cax=cbaxes, format="%.1f")

sns.scatterplot(data=df_wild,  x="a", y="w", hue='exp_level', palette='dark:#5A9_r', ax=axins1, legend=False)

# axins1.set_xticklabels(['0.1', '1', '10'])

x1, x2, y1, y2 = 0.05, 10, 5.6, 15

axins1.set_xlim(x1, x2)
axins1.set_ylim(y1, y2)

axins1.set_xlabel(None)
axins1.set_ylabel(None)
axins1.plot(x, y, color="k", linewidth=1.5)
axins1.hlines(y=beta*c, xmin=beta, xmax = 10, color="k", linewidth=1.5)
axins1.vlines(x=beta, ymin=beta*c, ymax = 15, color="k", linewidth=1.5)
#  Add the lines to indicate where the inset axis is coming from

mark_inset(ax[1], axins1, loc1=2, loc2=4, fc="none", ec="0.5", edgecolor="black")
plt.show()

# %%
url1='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/ad_ana_heatmap1_aw_1000_length_1.txt'
df_heatmap = pd.read_csv(url1,sep = ',', header=None)
url2='/content/drive/MyDrive/Colab Notebooks/heatmaps/ir_&_avg_w_data.txt'
df_wild = pd.read_csv(url2,delim_whitespace=True)
df_wild.columns= ['g_no','gene','te','ad','rue','a','w']

# df_heatmap.columns = ['alpha', 'omega','te','ad', 'rue']
# alpha_rates = df_heatmap.alpha.values.reshape(700, 700) #np.linspace(0,5,700);
# omega_rates = df_heatmap.omega.values.reshape(700, 700) #np.linspace(0,15,700);
# #xv,yv= np.meshgrid(alpha_rates,omega_rates)

alpha_rates = np.linspace(0.0,1000,1000);
omega_rates = np.linspace(0.0,1000,1000);
xv,yv= np.meshgrid(alpha_rates,omega_rates)
# f=df_heatmap.rue
# Z = f.values.reshape(700, 700)
fig, ax = plt.subplots(2,2, figsize=(10, 10), sharey=False)
texts = ['(A)', '(B)','(C)','(D)']
axes = fig.get_axes()

for a,l in zip(axes, texts):
    a.annotate(l, xy=(-0.3, 1.0), xycoords="axes fraction", fontsize=15)



# fig, ax = plt.subplots(1)
beta=30;
c=(1+np.sqrt(1));
x =np.linspace(0,beta,20)
y = c*x;

# plt.axhline(y=beta*c,color="r");
# plt.axvline(x=beta,color="r");
ax[0,0].plot(x, y, color="k", linewidth=1)
ax[0,0].hlines(y=beta*c, xmin=beta,xmax = 1000, color="k")
ax[0,0].vlines(x=beta, ymin=beta*c, ymax = 1000, color="k")
ax[0,0].plot(x, y, color="k", linewidth=1)
ax[0,0].set_yscale("log")
ax[0,0].set_xscale("log")
im=ax[0,0].pcolormesh(alpha_rates,omega_rates,df_heatmap,cmap ='YlGnBu', alpha=0.7)
fig.colorbar(im)
# sns.scatterplot(data=df_wild, x="a", y="w", hue="ad", palette="flare")
ax[0,0].set_title(r'$ \mathrm{L=1, \hspace{.4}\rho} $', pad=15) # adds some distance between the subtitle and the subplot
#plt.text(0, 0, "Corner", color='white', ha='center', va='center')
ax[0,0].text(150, 20, "MC", color='black', ha='center', va='center')
ax[0,0].text(10, 250, "LC", color='black', ha='center', va='center')
ax[0,0].text(150, 250, "HD", color='black', ha='center', va='center')
ax[0,0].set_xlabel(r'$ \mathrm{\alpha\hspace{.4}(s^{-1})} $')
ax[0,0].set_ylabel(r'$ \mathrm{\omega\hspace{.4}(s^{-1})} $')
# sns.move_legend(ax, "upper left", bbox_to_anchor=(1.3, 1))
################################### #Subfig 2 ###########################################


url1='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/te_ana_heatmap1_aw_1000_length_1.txt'
df_heatmap = pd.read_csv(url1,sep = ',', header=None)
url2='/content/drive/MyDrive/Colab Notebooks/heatmaps/ir_&_avg_w_data.txt'
df_wild = pd.read_csv(url2,delim_whitespace=True)
df_wild.columns= ['g_no','gene','te','ad','rue','a','w']

# df_heatmap.columns = ['alpha', 'omega','te','ad', 'rue']
# alpha_rates = df_heatmap.alpha.values.reshape(700, 700) #np.linspace(0,5,700);
# omega_rates = df_heatmap.omega.values.reshape(700, 700) #np.linspace(0,15,700);
# #xv,yv= np.meshgrid(alpha_rates,omega_rates)

alpha_rates = np.linspace(0.0,1000,1000);
omega_rates = np.linspace(0.0,1000,1000);
xv,yv= np.meshgrid(alpha_rates,omega_rates)
# f=df_heatmap.rue
# Z = f.values.reshape(700, 700)



# fig, ax = plt.subplots(1)
beta=30;
c=(1+np.sqrt(1));
x =np.linspace(0,beta,20)
y = c*x;

# plt.axhline(y=beta*c,color="r");
# plt.axvline(x=beta,color="r");
ax[0,1].plot(x, y, color="k", linewidth=1)
ax[0,1].hlines(y=beta*c, xmin=beta,xmax = 1000, color="k")
ax[0,1].vlines(x=beta, ymin=beta*c, ymax = 1000, color="k")
ax[0,1].plot(x, y, color="k", linewidth=1)
ax[0,1].set_yscale("log")
ax[0,1].set_xscale("log")
im=ax[0,1].pcolormesh(alpha_rates,omega_rates,df_heatmap,cmap ='YlGnBu', alpha=0.7)
fig.colorbar(im)
# sns.scatterplot(data=df_wild, x="a", y="w", hue="ad", palette="flare")

ax[0,1].text(150, 20, "MC", color='black', ha='center', va='center')
ax[0,1].text(10, 250, "LC", color='black', ha='center', va='center')
ax[0,1].text(150, 250, "HD", color='black', ha='center', va='center')

ax[0,1].set_xlabel(r'$ \mathrm{\alpha\hspace{.4}(s^{-1})} $')
ax[0,1].set_ylabel(r'$ \mathrm{\omega\hspace{.4}(s^{-1})} $', labelpad=-10)
ax[0,1].set_title(r'$ \mathrm{L=1, \hspace{.4}J\hspace{.4}(s^{-1})} $', pad=15) # adds some distance between the subtitle and the subplot

# sns.move_legend(ax, "upper left", bbox_to_anchor=(1.3, 1))

################################### #Subfig 3 ###########################################


url1='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/ad_ana_heatmap1_aw_1000_length_10.txt'
df_heatmap = pd.read_csv(url1,sep = ',', header=None)
url2='/content/drive/MyDrive/Colab Notebooks/heatmaps/ir_&_avg_w_data.txt'
df_wild = pd.read_csv(url2,delim_whitespace=True)
df_wild.columns= ['g_no','gene','te','ad','rue','a','w']

# df_heatmap.columns = ['alpha', 'omega','te','ad', 'rue']
# alpha_rates = df_heatmap.alpha.values.reshape(700, 700) #np.linspace(0,5,700);
# omega_rates = df_heatmap.omega.values.reshape(700, 700) #np.linspace(0,15,700);
# #xv,yv= np.meshgrid(alpha_rates,omega_rates)

alpha_rates = np.linspace(0.0,1000,1000);
omega_rates = np.linspace(0.0,1000,1000);
xv,yv= np.meshgrid(alpha_rates,omega_rates)
# f=df_heatmap.rue
# Z = f.values.reshape(700, 700)



beta=30;
c=(1+np.sqrt(10));
x =np.linspace(0,beta,20)
y = c*x;

# plt.axhline(y=beta*c,color="r");
# plt.axvline(x=beta,color="r");
ax[1,0].plot(x, y, color="k", linewidth=1)
ax[1,0].hlines(y=beta*c, xmin=beta,xmax = 1000, color="k")
ax[1,0].vlines(x=beta, ymin=beta*c, ymax = 1000, color="k")
ax[1,0].plot(x, y, color="k", linewidth=1)
ax[1,0].set_yscale("log")
ax[1,0].set_xscale("log")
im=ax[1,0].pcolormesh(alpha_rates,omega_rates,df_heatmap,cmap ='YlGnBu', alpha=0.7)
fig.colorbar(im)# sns.scatterplot(data=df_wild, x="a", y="w", hue="ad", palette="flare")


ax[1,0].text(150, 50, "MC", color='black', ha='center', va='center')
ax[1,0].text(10, 450, "LC", color='black', ha='center', va='center')
ax[1,0].text(150, 450, "HD", color='black', ha='center', va='center')
ax[1,0].set_xlabel(r'$ \mathrm{\alpha\hspace{.4}(s^{-1})} $')
ax[1,0].set_ylabel(r'$ \mathrm{\omega\hspace{.4}(s^{-1})} $')
ax[1,0].set_title(r'$ \mathrm{L=10, \hspace{.4}\rho} $', pad=15) # adds some distance between the subtitle and the subplot

# sns.move_legend(ax, "upper left", bbox_to_anchor=(1.3, 1))





#################################### Subfig 4 ###########################################

url1='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/te_ana_heatmap1_aw_1000_length_10.txt'
df_heatmap = pd.read_csv(url1,sep = ',', header=None)
# df_heatmap.columns = ['alpha', 'omega','te','ad', 'rue']
# alpha_rates = df_heatmap.alpha.values.reshape(700, 700) #np.linspace(0,5,700);
# omega_rates = df_heatmap.omega.values.reshape(700, 700) #np.linspace(0,15,700);
# #xv,yv= np.meshgrid(alpha_rates,omega_rates)
url2='/content/drive/MyDrive/Colab Notebooks/heatmaps/ir_&_avg_w_data.txt'
df_wild = pd.read_csv(url2,delim_whitespace=True)
df_wild.columns= ['g_no','gene','te','ad','rue','a','w']


alpha_rates = np.linspace(0.0,1000,1000);
omega_rates = np.linspace(0.0,1000,1000);
xv,yv= np.meshgrid(alpha_rates,omega_rates)
# f=df_heatmap.rue
# Z = f.values.reshape(700, 700)
beta=30;
c=(1+np.sqrt(10));
x =np.linspace(0,beta,20)
y = c*x;
# plt.axhline(y=beta*c,color="r");
# plt.axvline(x=beta,color="r");
# ax[1,1] = plt.subplot(2, 2, 2)
ax[1,1].plot(x, y, color="k", linewidth=1)
ax[1,1].hlines(y=beta*c, xmin=beta, xmax = 1000, color="k")
ax[1,1].vlines(x=beta, ymin=beta*c, ymax = 1000, color="k")

ax[1,1].set_yscale("log")
ax[1,1].set_xscale("log")
im=ax[1,1].pcolormesh(alpha_rates,omega_rates,df_heatmap,cmap ='YlGnBu', alpha=0.5)
fig.colorbar(im)
# sns.scatterplot(data=df_wild, x="a", y="w", hue="te",color='red', palette="flare")

ax[1,1].set_xlabel(r'$ \mathrm{\alpha\hspace{.4}(s^{-1})} $')
ax[1,1].set_ylabel(r'$ \mathrm{\omega\hspace{.4}(s^{-1})} $', labelpad=-10)
ax[1,1].set_title(r'$ \mathrm{L=10, \hspace{.4}J\hspace{.4}(s^{-1})} $', pad=15) # adds some distance between the subtitle and the subplot
ax[1,1].text(150, 50, "MC", color='black', ha='center', va='center')
ax[1,1].text(10, 450, "LC", color='black', ha='center', va='center')
ax[1,1].text(150, 450, "HD", color='black', ha='center', va='center')


#ax[1,1].text(0, 0, "Corner", color='white', ha='center', va='center')
# fig.subplots_adjust(hspace=0.3)
plt.subplots_adjust(top=0.9, hspace=0.3)
# sns.move_legend(ax, "upper left", bbox_to_anchor=(1.3, 1))
plt.show()
#,norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03,vmin=0, vmax=100.0, base=10)

# %%
#################################### Varying length of ribosome Fig 2 ###########################################


import matplotlib.pyplot as plt
import numpy as np

url1='/content/drive/MyDrive/Colab Notebooks/heatmaps/rue_ana_heatmap1_aw.txt'
df_heatmap = pd.read_csv(url1,sep = ',', header=None)
url2='/content/drive/MyDrive/Colab Notebooks/heatmaps/ir_&_avg_w_data.txt'
df_wild = pd.read_csv(url2,delim_whitespace=True)
df_wild.columns= ['g_no','gene','te','ad','rue','a','w']

# df_heatmap.columns = ['alpha', 'omega','te','ad', 'rue']
# alpha_rates = df_heatmap.alpha.values.reshape(700, 700) #np.linspace(0,5,700);
# omega_rates = df_heatmap.omega.values.reshape(700, 700) #np.linspace(0,15,700);
# #xv,yv= np.meshgrid(alpha_rates,omega_rates)

alpha_rates = np.linspace(0.0,5,700);
omega_rates = np.linspace(0.0,30,700);
xv,yv= np.meshgrid(alpha_rates,omega_rates)
# f=df_heatmap.rue
# Z = f.values.reshape(700, 700)
fig, ax = plt.subplots(1)
beta=1;
x =np.linspace(0,beta,20)

c2=(1+np.sqrt(1));
y2 = c2*x;
# plt.axhline(y=beta*c,color="r");
# plt.axvline(x=beta,color="r");
plt.plot(x, y2, color="#4b8bbe", linewidth=1, label ='L=1')
ax.hlines(y=beta*c2, xmin=1,xmax = 5,linewidth=1, color="#4b8bbe")
ax.vlines(x=beta, ymin=beta*c2, ymax = 30, linewidth=1, color="#4b8bbe")



c4=(1+np.sqrt(5));
y4 = c4*x;
# plt.axhline(y=beta*c,color="r");
# plt.axvline(x=beta,color="r");
plt.plot(x, y4, color="#41b883", linewidth=1, label ='L=5')
ax.hlines(y=beta*c4, xmin=1,xmax = 5,linewidth=1, color="#41b883")
ax.vlines(x=beta, ymin=beta*c4, ymax = 30,linewidth=1, color="#41b883")



c1=(1+np.sqrt(10));
y1 = c1*x;
# plt.axhline(y=beta*c,color="r");
# plt.axvline(x=beta,color="r");
plt.plot(x, y1, color="#f69824", linewidth=1, label ='L=10')
ax.hlines(y=beta*c1, xmin=1, xmax = 5,linewidth=1, color="#f69824")
ax.vlines(x=beta, ymin=beta*c1, ymax = 30,linewidth=1, color="#f69824")






c3 =(1+np.sqrt(30));
y3 = c3*x;
# plt.axhline(y=beta*c,color="r");
# plt.axvline(x=beta,color="r");
plt.plot(x, y3, color="r", linewidth=1, label ='L=30')
ax.hlines(y=beta*c3, xmin=1,xmax = 5, linewidth=1,color="r")
ax.vlines(x=beta, ymin=beta*c3, ymax = 30, linewidth=1,color="r")









plt.xlabel(r'$ \mathrm{\alpha\hspace{.4}(s^{-1})} $')
plt.ylabel(r'$ \mathrm{\omega\hspace{.4}(s^{-1})} $')
plt.legend(loc ="upper left", bbox_to_anchor=(1.0, 1))


# plt.legend(["l=10", "l=1", "l=30", "l=5"], loc ="lower right")
plt.yscale("log")
plt.xscale("log")
plt.xlim([0, 5])
plt.ylim([0, 30])
# plt.pcolormesh(alpha_rates,omega_rates,df_heatmap,cmap ='YlGnBu',alpha=0.2)
# plt.colorbar()
# sns.scatterplot(data=df_wild, x="a", y="w", hue="ad", palette="flare")
# sns.move_legend(ax, "upper left", bbox_to_anchor=(1.3, 1))

plt.show()
# Out:
# <ipython-input-36-950ccf79e900>:84: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim([0, 5])
# <ipython-input-36-950ccf79e900>:85: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim([0, 30])

# %%
#################################### Fig 3 ####################################
#################################### Varying ribosome recycling rate  in RUE heatmap Subfig 1  ###########################################


#url1='/content/drive/MyDrive/Colab Notebooks/heatmaps/rue_ana_heatmap1_aw_rr.txt'
#df_heatmap = pd.read_csv(url1,sep = ',', header=None)

#url2='/content/drive/MyDrive/Colab Notebooks/heatmaps/ir_&_avg_w_data.txt'
#df_wild = pd.read_csv(url2,delim_whitespace=True)
#df_wild.columns= ['g_no','gene','te','ad','rue ','a','w']

url3='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_3/alpha_eff_beta_gamma_1.txt'
gamma_1 = pd.read_csv(url3,delim_whitespace=True, header=0)
gamma_1.columns= ['alpha','omega']

url4='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_3/omega_eq_alpha_eff_c_gamma_1.txt'
linear_line1 = pd.read_csv(url4,delim_whitespace=True, header=0)
linear_line1.columns= ['alpha','omega']


first_occurence=(linear_line1['omega'] == 124.8683).idxmax()
first_occurence_x_value=linear_line1.alpha[first_occurence]
gamma_1.omega=pd.Series([124.8683]).append(gamma_1.omega).reset_index(drop=True)  # drop=True argument to drop the original index of gamma_1.omega
gamma_1.alpha=pd.Series([first_occurence_x_value]).append(gamma_1.alpha).reset_index(drop=True)
# gamma_1.omega=pd.concat([pd.Series([8.3246]), gamma_1.omega]).reset_index(drop=True)
# gamma_1.alpha=pd.concat([pd.Series([first_occurence_x_value]), gamma_1.omega]).reset_index(drop=True)


url5='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_3/alpha_eff_beta_gamma_2.txt'
gamma_2 = pd.read_csv(url5,delim_whitespace=True, header=0)
gamma_2.columns= ['alpha','omega']

url6='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_3/omega_eq_alpha_eff_c_gamma_2.txt'
linear_line2 = pd.read_csv(url6,delim_whitespace=True, header=0)
linear_line2.columns= ['alpha','omega']

first_occurence=(linear_line2['omega'] == 124.8683).idxmax()
first_occurence_x_value=linear_line2.alpha[first_occurence]
gamma_2.omega=pd.Series([124.8683]).append(gamma_2.omega).reset_index(drop=True)  # drop=True argument to drop the original index of gamma_1.omega
gamma_2.alpha=pd.Series([first_occurence_x_value]).append(gamma_2.alpha).reset_index(drop=True)
# gamma_2.omega=pd.concat([pd.Series([8.3246]), gamma_2.omega]).reset_index(drop=True)
# gamma_2.alpha=pd.concat([pd.Series([first_occurence_x_value]), gamma_2.omega]).reset_index(drop=True)

url7='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_3/alpha_eff_beta_gamma_3.txt'
gamma_3 = pd.read_csv(url7,delim_whitespace=True, header=0)
gamma_3.columns= ['alpha','omega']

url8='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_3/omega_eq_alpha_eff_c_gamma_3.txt'
linear_line3= pd.read_csv(url8,delim_whitespace=True, header=0)
linear_line3.columns= ['alpha','omega']

first_occurence=(linear_line3['omega'] == 124.8683).idxmax()
first_occurence_x_value=linear_line3.alpha[first_occurence]
gamma_3.omega=pd.Series([124.8683]).append(gamma_3.omega).reset_index(drop=True)  # drop=True argument to drop the original index of gamma_1.omega
gamma_3.alpha=pd.Series([first_occurence_x_value]).append(gamma_3.alpha).reset_index(drop=True)
# gamma_3.omega=pd.concat([pd.Series([8.3246]), gamma_3.omega]).reset_index(drop=True)
# gamma_3.alpha=pd.concat([pd.Series([first_occurence_x_value]), gamma_3.omega]).reset_index(drop=True)


url9='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_3/alpha_eff_beta_gamma_4.txt'
gamma_4 = pd.read_csv(url9,delim_whitespace=True, header=0)
gamma_4.columns= ['alpha','omega']

url10='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_3/omega_eq_alpha_eff_c_gamma_4.txt'
linear_line4 = pd.read_csv(url10,delim_whitespace=True, header=0)
linear_line4.columns= ['alpha','omega']

first_occurence=(linear_line4['omega'] == 124.8683).idxmax()
first_occurence_x_value=linear_line4.alpha[first_occurence]
gamma_4.omega=pd.Series([124.8683]).append(gamma_4.omega).reset_index(drop=True)  # drop=True argument to drop the original index of gamma_1.omega
gamma_4.alpha=pd.Series([first_occurence_x_value]).append(gamma_4.alpha).reset_index(drop=True)
# gamma_4.omega=pd.concat([pd.Series([8.3246]), gamma_4.omega]).reset_index(drop=True)
# gamma_4.alpha=pd.concat([pd.Series([first_occurence_x_value]), gamma_4.omega]).reset_index(drop=True)


url11='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_3/alpha_eff_beta_gamma_5.txt'
gamma_5 = pd.read_csv(url11,delim_whitespace=True, header=0)
gamma_5.columns= ['alpha','omega']

url12='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_3/omega_eq_alpha_eff_c_gamma_5.txt'
linear_line5 = pd.read_csv(url12,delim_whitespace=True, header=0)
linear_line5.columns= ['alpha','omega']

first_occurence=(linear_line5['omega'] == 124.8683).idxmax()
first_occurence_x_value=linear_line5.alpha[first_occurence]
gamma_5.omega=pd.Series([124.8683]).append(gamma_5.omega).reset_index(drop=True)  # drop=True argument to drop the original index of gamma_1.omega
gamma_5.alpha=pd.Series([first_occurence_x_value]).append(gamma_5.alpha).reset_index(drop=True)

# gamma_5.omega=pd.concat([pd.Series([8.3246]), gamma_5.omega]).reset_index(drop=True)
# gamma_5.alpha=pd.concat([pd.Series([first_occurence_x_value]), gamma_5.omega]).reset_index(drop=True)


fig, ax = plt.subplots(2,1, figsize=(10, 10), sharey=False)
texts = ['(A)', '(B)']
axes = fig.get_axes()

for a,l in zip(axes, texts):
    a.annotate(l, xy=(-0.2, 1.0), xycoords="axes fraction", fontsize=15)


alpha_rates = np.linspace(0.0,60,700);
omega_rates = np.linspace(0.0,200,700);
xv,yv= np.meshgrid(alpha_rates,omega_rates)
# f=df_heatmap.rue
# Z = f.values.reshape(700, 700)
beta=30;
c=(1+np.sqrt(10));
# x =np.linspace(0,beta,20)
# y = c*x;

# plt.yscale("log")
# plt.xscale("log")


#plt.axhline(y=beta*c, xmin = .77, xmax = 1, color="r");
#plt.axvline(x=beta, ymin = beta*c, ymax = 30, color="r");





ax[0].plot(gamma_5.alpha, gamma_5.omega, color="m", linewidth=1, label ='q=1')
ax[0].plot(linear_line5.alpha, linear_line5.omega, color="m", linewidth=1)

ax[0].plot(gamma_4.alpha, gamma_4.omega, color="g", linewidth=1, label ='q=0.75')
ax[0].plot(linear_line4.alpha, linear_line4.omega, color="g", linewidth=1)
ax[0].plot(gamma_3.alpha, gamma_3.omega, color="b", linewidth=1, label ='q=0.5')
ax[0].plot(linear_line3.alpha, linear_line3.omega, color="b", linewidth=1)
ax[0].plot(gamma_2.alpha, gamma_2.omega, color="r", linewidth=1, label ='q=0.25')
ax[0].plot(linear_line2.alpha, linear_line2.omega, color="r", linewidth=1)
ax[0].plot(gamma_1.alpha, gamma_1.omega, color="k", linewidth=1, label ='q=0.0')
ax[0].plot(linear_line1.alpha, linear_line1.omega, color="k", linewidth=1)

# sns.scatterplot(data=df_wild, x="a", y="w", hue="rue", palette="dark:#5A9_r")

ax[0].set_xlabel(r'$ \mathrm{\alpha\hspace{.4}(s^{-1})} $')
ax[0].set_ylabel(r'$ \mathrm{\omega\hspace{.4}(s^{-1})} $')
ax[0].legend(loc ="upper left", bbox_to_anchor=(1.0, 1))


ax[0].set_xlim([0, 60])
ax[0].set_ylim([0, 200])




#################################### recycling reduces the area of LD regime. Subfig 2 ###########################################



# create two arrays
gamma =  np.array([0, 0.25, 0.5, 0.75, 1])
  # array of 100 values between 0 and 10



area_ld = np.array([4127.0, 3843.0, 3559.1, 3275.1, 2991.1])
               # array of sine values for each x value
area_mc = np.array([ 5619.1, 5731.6, 5844.1, 5956.6, 6069.1])

area_hd = np.array([2254.0, 2425.4, 2596.9, 2768.3, 2939.8])

# plot the arrays



df1 = pd.DataFrame({'X': gamma, 'Y': area_ld})
df2 = pd.DataFrame({'X': gamma, 'Y': area_mc})
df3 = pd.DataFrame({'X': gamma, 'Y': area_hd})

# create a scatter plot using seaborn
sns.scatterplot(data=df1, x='X', y='Y',label ='LD', ax=ax[1])
sns.scatterplot(data=df2, x='X', y='Y',label ='MC', ax=ax[1])
sns.scatterplot(data=df3, x='X', y='Y',label ='HD', ax=ax[1])
ax[1].plot(gamma, area_ld)
ax[1].plot(gamma, area_mc)
ax[1].plot(gamma, area_hd)
ax[1].set_xlabel(r'$ \mathrm{\gamma\hspace{.4}(s^{-1})} $')
ax[1].set_ylabel(r'$ \mathrm{Area\hspace{.4}} $')
ax[1].legend(loc ="upper left", bbox_to_anchor=(1.0, 1))


ax[1].set_xlim([0, 1])
# ax[1].set_ylim([15, 28])
# Out:
# <ipython-input-5-b1ccde92a6c5>:23: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gamma_1.omega=pd.Series([124.8683]).append(gamma_1.omega).reset_index(drop=True)  # drop=True argument to drop the original index of gamma_1.omega
# <ipython-input-5-b1ccde92a6c5>:24: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gamma_1.alpha=pd.Series([first_occurence_x_value]).append(gamma_1.alpha).reset_index(drop=True)
# <ipython-input-5-b1ccde92a6c5>:39: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gamma_2.omega=pd.Series([124.8683]).append(gamma_2.omega).reset_index(drop=True)  # drop=True argument to drop the original index of gamma_1.omega
# ...

# %%
#################################### Fig 11 ###########################################


# heatmap alpha beta
################ AD ##############
import matplotlib.pyplot as plt
import numpy as np

url1='/content/drive/MyDrive/Colab Notebooks/heatmaps/headway_distance_ana_heatmap_aw.txt'
df_heatmap = pd.read_csv(url1,sep = ',', header=None)
url2='/content/drive/MyDrive/Colab Notebooks/heatmaps/ir_&_avg_w_data.txt'
df_wild = pd.read_csv(url2,delim_whitespace=True)
df_wild.columns= ['g_no','gene','te','ad','rue','a','w']


# df_heatmap.columns = ['alpha', 'omega','te','ad', 'rue']
# alpha_rates = df_heatmap.alpha.values.reshape(700, 700) #np.linspace(0,5,700);
# omega_rates = df_heatmap.omega.values.reshape(700, 700) #np.linspace(0,15,700);
# #xv,yv= np.meshgrid(alpha_rates,omega_rates)

alpha_rates = np.linspace(0.0,1,100);
omega_rates = np.linspace(0.0,12,100);
xv,yv= np.meshgrid(alpha_rates,omega_rates)
# f=df_heatmap.rue
# Z = f.values.reshape(700, 700)
fig, ax = plt.subplots(1)
beta=0.5;
c=(1+np.sqrt(10));
x =np.linspace(0,beta,20)
y = c*x;
# plt.axhline(y=beta*c,color="r");
# plt.axvline(x=beta,color="r");
plt.plot(x, y, color="k", linewidth=1.5)
ax.hlines(y=beta*c, xmin=0.5,xmax = 1, color="k", linewidth=1.5)
ax.vlines(x=beta, ymin=beta*c, ymax = 12, color="k", linewidth=1.5)
plt.plot(x, y, color="k", linewidth=1.5)
plt.yscale("log")
plt.xscale("log")
cax=ax.pcolormesh(alpha_rates,omega_rates,df_heatmap,cmap ='YlGnBu', alpha=0.5, vmin=0, vmax=50)
cb = fig.colorbar(cax)
sns.scatterplot(data=df_wild, x="a", y="w", hue="ad", palette="flare")
plt.xlim(0, 1)

plt.xlabel(r'$ \mathrm{\alpha\hspace{.4}(s^{-1})} $')
plt.ylabel(r'$ \mathrm{\omega\hspace{.4}(s^{-1})} $')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1.3, 1))

plt.show()
# Out:
# <ipython-input-6-ef5def089223>:41: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(0, 1)

# %%
########################################################################### TRIAL CODE ##################################################################################################



#################################### RUE IS OPTIMIZED. Subfig 1 ###########################################


url1='/content/drive/MyDrive/Colab Notebooks/heatmaps/rue_ana_heatmap1_aw.txt'
df_heatmap = pd.read_csv(url1,sep = ',', header=None)

url2='/content/drive/MyDrive/Colab Notebooks/heatmaps/colab_exp_level_ir.txt'
df_wild = pd.read_csv(url2,delim_whitespace=True)
df_wild.columns= ['g_no','gene','te','ad','rue','a','w','exp_level']

fig, ax = plt.subplots(2,1, figsize=(10, 10), sharey=False)
texts = ['(A)', '(B)']
axes = fig.get_axes()

for a,l in zip(axes, texts):
    a.annotate(l, xy=(-0.2, 1.0), xycoords="axes fraction", fontsize=15)

alpha_rates = np.linspace(0.0,5,700);
omega_rates = np.linspace(0.0,30,700);
xv,yv= np.meshgrid(alpha_rates,omega_rates)
# f=df_heatmap.rue
# Z = f.values.reshape(700, 700)
beta=1;
c=(1+np.sqrt(10));
x =np.linspace(0,beta,20)
y = c*x;

ax[0].set_yscale("log")
ax[0].set_xscale("log")

im=ax[0].pcolormesh(alpha_rates,omega_rates,df_heatmap,cmap ='YlGnBu', alpha=0.5)
fig.colorbar(im)
#plt.axhline(y=beta*c, xmin = .77, xmax = 1, color="r");
#plt.axvline(x=beta, ymin = beta*c, ymax = 30, color="r");
ax[0].plot(x, y, color="k", linewidth=1.5)
ax[0].hlines(y=beta*c, xmin=1,xmax = 5, color="k", linewidth=1.5)
ax[0].vlines(x=beta, ymin=beta*c, ymax = 30, color="k", linewidth=1.5)

sns.scatterplot(data=df_wild, x="a", y="w", hue="exp_level", palette="dark:#5A9_r", ax=ax[0])

ax[0].set_xlabel(r'$ \mathrm{\alpha\hspace{.4}(s^{-1})} $')
ax[0].set_ylabel(r'$ \mathrm{\omega\hspace{.4}(s^{-1})} $')
ax[0].set_title('Ribosome Utilization Efficiency (RUE)')

ax[0].legend(loc="upper left", bbox_to_anchor=(1.15, 1))





#################################### Subfig2  ###########################################

import matplotlib.pyplot as plt
import numpy as np

url1='/content/drive/MyDrive/Colab Notebooks/heatmaps/te_ana_heatmap1_aw.txt'
df_heatmap = pd.read_csv(url1,sep = ',', header=None)
# df_heatmap.columns = ['alpha', 'omega','te','ad', 'rue']
# alpha_rates = df_heatmap.alpha.values.reshape(700, 700) #np.linspace(0,5,700);
# omega_rates = df_heatmap.omega.values.reshape(700, 700) #np.linspace(0,15,700);
# #xv,yv= np.meshgrid(alpha_rates,omega_rates)
url2='/content/drive/MyDrive/Colab Notebooks/heatmaps/colab_exp_level_ir.txt'
df_wild = pd.read_csv(url2,delim_whitespace=True)
df_wild.columns= ['g_no','gene','te','ad','rue','a','w','exp_level']


alpha_rates = np.linspace(0.0,5,700);
omega_rates = np.linspace(0.0,30,700);
xv,yv= np.meshgrid(alpha_rates,omega_rates)
# f=df_heatmap.rue
# Z = f.values.reshape(700, 700)
beta=1;
c=(1+np.sqrt(10));
x =np.linspace(0,beta,20)
y = c*x;
# plt.axhline(y=beta*c,color="r");
# plt.axvline(x=beta,color="r");

ax[1].set_yscale("log")
ax[1].set_xscale("log")
im=ax[1].pcolormesh(alpha_rates,omega_rates,df_heatmap,cmap ='YlGnBu', alpha=0.5)
fig.colorbar(im)
ax[1].plot(x, y, color="k", linewidth=1.5)
ax[1].hlines(y=beta*c, xmin=1,xmax = 5, color="k", linewidth=1.5)
ax[1].vlines(x=beta, ymin=beta*c, ymax = 30, color="k", linewidth=1.5)
cmap = plt.get_cmap('Accent')
sns.scatterplot(data=df_wild, x="a", y="w", hue="exp_level", palette="dark:#5A9_r", c=df_wild["exp_level"], cmap=cmap, ax=ax[1], vmin=000, vmax=100)

ax[1].set_xlabel(r'$ \mathrm{\alpha\hspace{.4}(s^{-1})} $')
ax[1].set_ylabel(r'$ \mathrm{\omega\hspace{.4}(s^{-1})} $')
ax[1].set_title('Flux (J)')
ax[1].legend(loc="upper left", bbox_to_anchor=(1.15, 1))   # moves legend out of plot to some position
fig.subplots_adjust(hspace=0.3)   #  Adjust the spacing between subplots
plt.show()

#,norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03,vmin=0, vmax=100.0, base=10)

# %%
url1='/content/drive/MyDrive/Colab Notebooks/heatmaps/total_cost_J_1000000.txt'
df_heatmap = pd.read_csv(url1,sep = ',', header=None)


alpha_rates = np.linspace(0.0,1,700);
omega_rates = np.linspace(0.0,5,700);
xv,yv= np.meshgrid(alpha_rates,omega_rates)
# f=df_heatmap.rue
# Z = f.values.reshape(700, 700)
fig, ax = plt.subplots(2,2, figsize=(10, 10), sharey=False)
texts = ['(A)', '(B)','(C)','(D)']
axes = fig.get_axes()

for a,l in zip(axes, texts):
    a.annotate(l, xy=(-0.2, 1.0), xycoords="axes fraction", fontsize=15)



# fig, ax = plt.subplots(1)
beta=0.1;
c=(1+np.sqrt(10));
x =np.linspace(0,beta,20)
y = c*x;

# plt.axhline(y=beta*c,color="r");
# plt.axvline(x=beta,color="r");
ax[0,0].plot(x, y, color="k", linewidth=1)
ax[0,0].hlines(y=beta*c, xmin=beta,xmax = 1, color="k")
ax[0,0].vlines(x=beta, ymin=beta*c, ymax = 5, color="k")
ax[0,0].plot(x, y, color="k", linewidth=1)
ax[0,0].set_yscale("log")
ax[0,0].set_xscale("log")
im=ax[0,0].pcolormesh(alpha_rates,omega_rates,df_heatmap,cmap ='YlGnBu', alpha=0.7)
fig.colorbar(im)
# sns.scatterplot(data=df_wild, x="a", y="w", hue="ad", palette="flare")
ax[0,0].set_title(r'$ \mathrm{j=1, \hspace{.4}Total\hspace{.4}cost} $', pad=15) # adds some distance between the subtitle and the subplot
ax[0,0].text(0.4, 0.2, "MC", color='black', ha='center', va='center')
ax[0,0].text(0.03, 2, "LC", color='black', ha='center', va='center')
ax[0,0].text(0.4, 2, "HD", color='black', ha='center', va='center')#plt.text(0, 0, "Corner", color='white', ha='center', va='center')
ax[0,0].set_xlabel(r'$ \mathrm{\alpha\hspace{.4}(s^{-1})} $')
ax[0,0].set_ylabel(r'$ \mathrm{\omega\hspace{.4}(s^{-1})} $', labelpad=-10)
# sns.move_legend(ax, "upper left", bbox_to_anchor=(1.3, 1))
################################### #Subfig 2 ###########################################


url1='/content/drive/MyDrive/Colab Notebooks/heatmaps/total_cost_J_1000.txt'
df_heatmap = pd.read_csv(url1,sep = ',', header=None)


alpha_rates = np.linspace(0.0,1,700);
omega_rates = np.linspace(0.0,5,700);
xv,yv= np.meshgrid(alpha_rates,omega_rates)
# f=df_heatmap.rue
# Z = f.values.reshape(700, 700)



# fig, ax = plt.subplots(1)
beta=0.1;
c=(1+np.sqrt(10));
x =np.linspace(0,beta,20)
y = c*x;

# plt.axhline(y=beta*c,color="r");
# plt.axvline(x=beta,color="r");
ax[0,1].plot(x, y, color="k", linewidth=1)
ax[0,1].hlines(y=beta*c, xmin=beta,xmax = 1, color="k")
ax[0,1].vlines(x=beta, ymin=beta*c, ymax = 5, color="k")
ax[0,1].plot(x, y, color="k", linewidth=1)
ax[0,1].set_yscale("log")
ax[0,1].set_xscale("log")
im=ax[0,1].pcolormesh(alpha_rates,omega_rates,df_heatmap,cmap ='YlGnBu', alpha=0.7)
fig.colorbar(im)
# sns.scatterplot(data=df_wild, x="a", y="w", hue="ad", palette="flare")
ax[0,1].text(0.4, 0.2, "MC", color='black', ha='center', va='center')
ax[0,1].text(0.03, 2, "LC", color='black', ha='center', va='center')
ax[0,1].text(0.4, 2, "HD", color='black', ha='center', va='center')
ax[0,1].set_xlabel(r'$ \mathrm{\alpha\hspace{.4}(s^{-1})} $')
ax[0,1].set_ylabel(r'$ \mathrm{\omega\hspace{.4}(s^{-1})} $', labelpad=-10)
ax[0,1].set_title(r'$ \mathrm{J=1000, \hspace{.4}J\hspace{.4}(s^{-1})} $', pad=15) # adds some distance between the subtitle and the subplot

# sns.move_legend(ax, "upper left", bbox_to_anchor=(1.3, 1))

################################### #Subfig 3 ###########################################


url1='/content/drive/MyDrive/Colab Notebooks/heatmaps/total_cost_J_100.txt'
df_heatmap = pd.read_csv(url1,sep = ',', header=None)

alpha_rates = np.linspace(0.0,1,700);
omega_rates = np.linspace(0.0,5,700);
xv,yv= np.meshgrid(alpha_rates,omega_rates)
# f=df_heatmap.rue
# Z = f.values.reshape(700, 700)



beta=0.1;
c=(1+np.sqrt(10));
x =np.linspace(0,beta,20)
y = c*x;

# plt.axhline(y=beta*c,color="r");
# plt.axvline(x=beta,color="r");
ax[1,0].plot(x, y, color="k", linewidth=1)
ax[1,0].hlines(y=beta*c, xmin=beta,xmax = 1, color="k")
ax[1,0].vlines(x=beta, ymin=beta*c, ymax = 5, color="k")
ax[1,0].plot(x, y, color="k", linewidth=1)
ax[1,0].set_yscale("log")
ax[1,0].set_xscale("log")
im=ax[1,0].pcolormesh(alpha_rates,omega_rates,df_heatmap,cmap ='YlGnBu', alpha=0.7)
fig.colorbar(im)# sns.scatterplot(data=df_wild, x="a", y="w", hue="ad", palette="flare")

ax[1,0].text(0.4, 0.2, "MC", color='black', ha='center', va='center')
ax[1,0].text(0.03, 2, "LC", color='black', ha='center', va='center')
ax[1,0].text(0.4, 2, "HD", color='black', ha='center', va='center')
ax[1,0].set_xlabel(r'$ \mathrm{\alpha\hspace{.4}(s^{-1})} $')
ax[1,0].set_ylabel(r'$ \mathrm{\omega\hspace{.4}(s^{-1})} $', labelpad=-10)
ax[1,0].set_title(r'$ \mathrm{J=100, \hspace{.4}\rho} $', pad=15) # adds some distance between the subtitle and the subplot

# sns.move_legend(ax, "upper left", bbox_to_anchor=(1.3, 1))




#################################### SubFig 4 ###########################################


url1='/content/drive/MyDrive/Colab Notebooks/heatmaps/total_cost_J_5.txt'
df_heatmap = pd.read_csv(url1,sep = ',', header=None)

alpha_rates = np.linspace(0.0,1,700);
omega_rates = np.linspace(0.0,5,700);
xv,yv= np.meshgrid(alpha_rates,omega_rates)
# f=df_heatmap.rue
# Z = f.values.reshape(700, 700)
beta=0.1;
c=(1+np.sqrt(10));
x =np.linspace(0,beta,20)
y = c*x;
# plt.axhline(y=beta*c,color="r");
# plt.axvline(x=beta,color="r");
# ax[1,1] = plt.subplot(2, 2, 2)
ax[1,1].plot(x, y, color="k", linewidth=1)
ax[1,1].hlines(y=beta*c, xmin=beta,xmax = 1, color="k")
ax[1,1].vlines(x=beta, ymin=beta*c, ymax = 5, color="k")

ax[1,1].set_yscale("log")
ax[1,1].set_xscale("log")
im=ax[1,1].pcolormesh(alpha_rates,omega_rates,df_heatmap,cmap ='YlGnBu', alpha=0.5)
fig.colorbar(im)
# sns.scatterplot(data=df_wild, x="a", y="w", hue="te",color='red', palette="flare")

ax[1,1].set_xlabel(r'$ \mathrm{\alpha\hspace{.4}(s^{-1})} $')
ax[1,1].set_ylabel(r'$ \mathrm{\omega\hspace{.4}(s^{-1})} $', labelpad=-10)
ax[1,1].set_title(r'$ \mathrm{J=5, \hspace{.4}J\hspace{.4}(s^{-1})} $', pad=15) # adds some distance between the subtitle and the subplot
ax[1,1].text(0.4, 0.2, "MC", color='black', ha='center', va='center')
ax[1,1].text(0.03, 2, "LC", color='black', ha='center', va='center')
ax[1,1].text(0.4, 2, "HD", color='black', ha='center', va='center')
#ax[1,1].text(0, 0, "Corner", color='white', ha='center', va='center')
# fig.subplots_adjust(hspace=0.3)
plt.subplots_adjust(top=0.9, hspace=0.3)
# sns.move_legend(ax, "upper left", bbox_to_anchor=(1.3, 1))
plt.show()
#,norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03,vmin=0, vmax=100.0, base=10)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the range of beta and alpha
beta = np.linspace(1, 50, 50)
alpha = np.linspace(1, 50, 50)

# Create a meshgrid for the beta and alpha values
beta_mesh, alpha_mesh = np.meshgrid(beta, alpha)

# Calculate the value of c
c = 1 + np.sqrt(10)

# Calculate the values of w for each plane
w_beta = beta_mesh * c
w_alpha = alpha_mesh * c
w_alpha_beta = alpha_mesh

# Create a figure and 3D subplot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the intersection of the three planes
ax.plot_surface(beta_mesh, alpha_mesh, w_beta, color='blue', alpha=0.5)
ax.plot_surface(beta_mesh, alpha_mesh, w_alpha, color='green', alpha=0.5)
ax.plot_surface(beta_mesh, alpha_mesh, w_alpha_beta, color='red', alpha=0.5)

# Set labels for axes
ax.set_xlabel('Beta')
ax.set_ylabel('Alpha')
ax.set_zlabel('W')

# Show the plot
plt.show()

# %%
#################################### Fig 4  official ###########################################

#################################### RUE IS OPTIMIZED. Subfig 1 ###########################################

url1='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/rue_ana_heatmap1_aw_final_length_10.txt'
df_heatmap = pd.read_csv(url1,sep = ',', header=None)
url2='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/te_ad_rue_exp_ir_w.txt'
df_wild = pd.read_csv(url2,delim_whitespace=True)
df_wild.columns= ['g_no','gene','gene_name2','te','ad','rue','exp_level','a','w']
url3='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/rue_ana_heatmap1_aw_final_subset_length_10.txt'
df_subset_heatmap = pd.read_csv(url3,sep = ',', header=None)


fig, ax = plt.subplots(2,1, figsize=(10, 10), sharey=False)
texts = ['(A)', '(B)']
axes = fig.get_axes()

for a,l in zip(axes, texts):
    a.annotate(l, xy=(-0.2, 1.0), xycoords="axes fraction", fontsize=15)

alpha_rates = np.linspace(0.0,60,10000);
omega_rates = np.linspace(0.0,200,1000);
alpha_rates1 = np.linspace(0.05,10,10000);
omega_rates1 = np.linspace(5,15,1000);
xv,yv= np.meshgrid(alpha_rates,omega_rates)
# f=df_heatmap.rue
# Z = f.values.reshape(700, 700)
beta=30;
c=(1+np.sqrt(10));
x =np.linspace(0,beta,20)
y = c*x;

ax[0].set_yscale("log")
ax[0].set_xscale("log")

im=ax[0].pcolormesh(alpha_rates,omega_rates,df_heatmap,cmap ='YlGnBu', alpha=0.5)
fig.colorbar(im)
#plt.axhline(y=beta*c, xmin = .77, xmax = 1, color="r");
#plt.axvline(x=beta, ymin = beta*c, ymax = 30, color="r");
ax[0].plot(x, y, color="k", linewidth=1.5)
ax[0].hlines(y=beta*c, xmin=beta, xmax = 60, color="k", linewidth=1.5)
ax[0].vlines(x=beta, ymin=beta*c, ymax = 200, color="k", linewidth=1.5)
# sns.scatterplot(data=df_wild, x="a", y="w", hue="rue", palette="dark:#5A9_r", ax=ax[0])
sns.scatterplot(data=df_wild, x="a", y="w", hue="exp_level", palette="dark:#5A9_r", ax=ax[0])

ax[0].set_xlabel(r'$ \mathrm{\alpha\hspace{.4}(s^{-1})} $')
ax[0].set_ylabel(r'$ \mathrm{\omega\hspace{.4}(s^{-1})} $')
ax[0].set_title('Ribosome Utilization Efficiency (RUE)')

ax[0].legend(title="Expression level", loc="upper left", bbox_to_anchor=(1.52, 0.39))

# Create an inset axis
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset



# Create the inset axis
# axins=inset_axes(ax[0], width="40%", height="40%", loc="upper left")
inset_pos = [1.3, 0.4, 0.6, 0.6]  # [x, y, width, height]
axins = inset_axes(ax[0], width="70%", height="70%", loc='upper left', bbox_to_anchor=inset_pos, bbox_transform=ax[0].transAxes)

# Plot the zoomed-in region in the inset axis
axins.pcolormesh(alpha_rates1,omega_rates1,df_subset_heatmap,cmap ='YlGnBu', alpha=0.5)
cbaxes = inset_axes(axins, width="5%", height="100%", loc='upper right', bbox_to_anchor=(0.15, 0.036, 1, 1), bbox_transform=axins.transAxes)
cbar = plt.colorbar(axins.collections[0], cax=cbaxes, format="%.1f")
sns.scatterplot(data=df_wild,  x="a", y="w", hue='exp_level', palette='dark:#5A9_r', ax=axins, legend=False)
x1, x2, y1, y2 = 0.05, 10, 5.6, 15

axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
# axins.set_yticklabels(['10'])

axins.set_yscale("log")
axins.set_xscale("log")
# axins.set_yticks([1,10])

# axins.set_xticklabels('')
# axins.set_yticklabels('')
axins.set_xlabel(None)
axins.set_ylabel(None)
axins.plot(x, y, color="k", linewidth=1.5)
axins.hlines(y=beta*c, xmin=beta, xmax = 10, color="k", linewidth=1.5)
axins.vlines(x=beta, ymin=beta*c, ymax = 15, color="k", linewidth=1.5)
# ax[0].indicate_inset_zoom(axins)
mark_inset(ax[0], axins, loc1=2, loc2=4, fc="none", ec="0.5",edgecolor="black")


#################################### Subfig2  ###########################################

import matplotlib.pyplot as plt
import numpy as np

url1='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/te_ana_heatmap1_aw_final_length_10.txt'
df_heatmap = pd.read_csv(url1,sep = ',', header=None)

url2='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/te_ana_heatmap1_aw_final_subset_length_10.txt'
df_subset_heatmap = pd.read_csv(url2,sep = ',', header=None)

beta=30;
c=(1+np.sqrt(10));
x =np.linspace(0,beta,20)
y = c*x;
ax[1].set_yscale("log")
ax[1].set_xscale("log")
im=ax[1].pcolormesh(alpha_rates,omega_rates,df_heatmap,cmap ='YlGnBu', alpha=0.5)
fig.colorbar(im)
ax[1].plot(x, y, color="k", linewidth=1.5)
ax[1].hlines(y=beta*c, xmin=beta, xmax = 60, color="k", linewidth=1.5)
ax[1].vlines(x=beta, ymin=beta*c, ymax = 200, color="k", linewidth=1.5)

sns.scatterplot(data=df_wild, x="a", y="w", hue="exp_level", palette="dark:#5A9_r",ax=ax[1])

ax[1].set_xlabel(r'$ \mathrm{\alpha\hspace{.4}(s^{-1})} $')
ax[1].set_ylabel(r'$ \mathrm{\omega\hspace{.4}(s^{-1})} $')
ax[1].set_title('Flux (J)')
ax[1].legend(title="Expression level", loc="upper left", bbox_to_anchor=(1.52, 0.39))   # moves legend out of plot to some position
fig.subplots_adjust(hspace=0.3)   #  Adjust the spacing between subplots

# Create an inset axis
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset

# # Define the extent for the image (x-axis min, x-axis max, y-axis min, y-axis max)
# extent = (0, 60, 0, 200)

# loc=[0.5 0.5, 0.47, 0.47]"upper right"width="40%", height="40%",

# Create the inset axis

#axins1=inset_axes(ax[1], width="40%", height="40%", loc="upper left")
inset_pos = [1.3, 0.4, 0.6, 0.6]  # [x, y, width, height]
# axins1=inset_axes(ax[1], width="40%", height="40%", bbox_to_anchor=inset_pos)
axins1 = inset_axes(ax[1], width="70%", height="70%", loc='upper left', bbox_to_anchor=inset_pos, bbox_transform=ax[1].transAxes)

# axins = inset_axes(ax[1],  width="10%", height="10%", bbox_to_anchor=(1,0.2, 0.47, 0.17), bbox_transform=ax[1].transAxes)


# Plot the zoomed-in region in the inset axis
axins1.set_yscale("log")
axins1.set_xscale("log")
axins1.pcolormesh(alpha_rates1, omega_rates1, df_subset_heatmap, cmap ='YlGnBu', alpha=0.5)
cbaxes = inset_axes(axins1, width="5%", height="100%", loc='upper right', bbox_to_anchor=(0.15, 0.036, 1 ,1), bbox_transform=axins1.transAxes) # width,height% of colorbar,bbox=(x,y,width,height)
cbar = plt.colorbar(axins1.collections[0], cax=cbaxes, format="%.1f")

sns.scatterplot(data=df_wild,  x="a", y="w", hue='exp_level', palette='dark:#5A9_r', ax=axins1, legend=False)

# axins1.set_xticklabels(['0.1', '1', '10'])

x1, x2, y1, y2 = 0.05, 10, 5.6, 15

axins1.set_xlim(x1, x2)
axins1.set_ylim(y1, y2)
# axins1.set_yticklabels([10])
# axins1.set_yticks([10])
axins1.set_xlabel(None)
axins1.set_ylabel(None)
axins1.plot(x, y, color="k", linewidth=1.5)
axins1.hlines(y=beta*c, xmin=beta, xmax = 10, color="k", linewidth=1.5)
axins1.vlines(x=beta, ymin=beta*c, ymax = 15, color="k", linewidth=1.5)
#  Add the lines to indicate where the inset axis is coming from

mark_inset(ax[1], axins1, loc1=2, loc2=4, fc="none", ec="0.5", edgecolor="black")


# # axis.indicate_inset_zoom(axin)
# ax[1].indicate_inset_zoom(axins)

plt.show()

# fig.savefig("FIG_4.jpg", transparent=True, bbox_inches='tight', pad_inches=0,dpi=1000 )

# from google.colab import files

# files.download('/content/FIG_4.jpg')
# Out:
# /tmp/ipykernel_5065/844593441.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_wild = pd.read_csv(url2,delim_whitespace=True)

# %%
# Compute median expression level
median_exp = df_wild['exp_level'].median()

# Split into two groups
high_exp = df_wild[df_wild['exp_level'] > median_exp]
low_exp  = df_wild[df_wild['exp_level'] <= median_exp]

# Compute average RUE
avg_rue_high = high_exp['rue'].mean()
avg_rue_low  = low_exp['rue'].mean()

print("Median expression level:", median_exp)
print("Average RUE (above median):", avg_rue_high)
print("Average RUE (below median):", avg_rue_low)
# Out:
# Median expression level: 100.0
# Average RUE (above median): 8.380335396039603
# Average RUE (below median): 7.654279999999999

# %%
from google.colab import drive
drive.mount('/content/drive')
import seaborn as sns;sns.set_theme()
sns.set_color_codes()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import interp2d
import matplotlib.colors as colors

# %matplotlib inline
sns.set_style('white')
sns.set_style("ticks")
# Out:
# Mounted at /content/drive

# %%
#################################### Fig 4  official ###########################################

#################################### RUE IS OPTIMIZED. Subfig 1 ###########################################

url1='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/rue_ana_heatmap1_aw_final_length_10.txt'
df_heatmap = pd.read_csv(url1,sep = ',', header=None)
url2='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/te_ad_rue_exp_ir_w.txt'
df_wild = pd.read_csv(url2,delim_whitespace=True)
df_wild.columns= ['g_no','gene','gene_name2','te','ad','rue','exp_level','a','w']
url3='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/rue_ana_heatmap1_aw_final_subset_length_10.txt'
df_subset_heatmap = pd.read_csv(url3,sep = ',', header=None)


fig, ax = plt.subplots(2,1, figsize=(10, 10), sharey=False)
texts = ['(A)', '(B)']
axes = fig.get_axes()

for a,l in zip(axes, texts):
    a.annotate(l, xy=(-0.2, 1.0), xycoords="axes fraction", fontsize=15)

alpha_rates = np.linspace(0.0,60,10000);
omega_rates = np.linspace(0.0,200,1000);
alpha_rates1 = np.linspace(0.05,10,10000);
omega_rates1 = np.linspace(5,15,1000);
xv,yv= np.meshgrid(alpha_rates,omega_rates)
# f=df_heatmap.rue
# Z = f.values.reshape(700, 700)
beta=30;
c=(1+np.sqrt(10));
x =np.linspace(0,beta,20)
y = c*x;

ax[0].set_yscale("log")
ax[0].set_xscale("log")

im=ax[0].pcolormesh(alpha_rates,omega_rates,df_heatmap,cmap ='YlGnBu', alpha=0.5)
fig.colorbar(im)
#plt.axhline(y=beta*c, xmin = .77, xmax = 1, color="r");
#plt.axvline(x=beta, ymin = beta*c, ymax = 30, color="r");
ax[0].plot(x, y, color="k", linewidth=1.5)
ax[0].hlines(y=beta*c, xmin=beta, xmax = 60, color="k", linewidth=1.5)
ax[0].vlines(x=beta, ymin=beta*c, ymax = 200, color="k", linewidth=1.5)
# sns.scatterplot(data=df_wild, x="a", y="w", hue="rue", palette="dark:#5A9_r", ax=ax[0])
sns.scatterplot(data=df_wild, x="a", y="w", hue="exp_level", palette="dark:#5A9_r", ax=ax[0])

ax[0].set_xlabel(r'$ \mathrm{\alpha\hspace{.4}(s^{-1})} $')
ax[0].set_ylabel(r'$ \mathrm{\omega\hspace{.4}(s^{-1})} $')
ax[0].set_title('Ribosome Utilization Efficiency (RUE)')

ax[0].legend(title="Expression level", loc="upper left", bbox_to_anchor=(1.52, 0.39))

# Create an inset axis
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset



# Create the inset axis
# axins=inset_axes(ax[0], width="40%", height="40%", loc="upper left")
inset_pos = [1.3, 0.4, 0.6, 0.6]  # [x, y, width, height]
axins = inset_axes(ax[0], width="70%", height="70%", loc='upper left', bbox_to_anchor=inset_pos, bbox_transform=ax[0].transAxes)

# Plot the zoomed-in region in the inset axis
axins.pcolormesh(alpha_rates1,omega_rates1,df_subset_heatmap,cmap ='YlGnBu', alpha=0.5)
cbaxes = inset_axes(axins, width="5%", height="100%", loc='upper right', bbox_to_anchor=(0.15, 0.036, 1, 1), bbox_transform=axins.transAxes)
cbar = plt.colorbar(axins.collections[0], cax=cbaxes, format="%.1f")
sns.scatterplot(data=df_wild,  x="a", y="w", hue='exp_level', palette='dark:#5A9_r', ax=axins, legend=False)
x1, x2, y1, y2 = 0.05, 10, 5.6, 15

axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
# axins.set_yticklabels(['10'])

axins.set_yscale("log")
axins.set_xscale("log")
# axins.set_yticks([1,10])

# axins.set_xticklabels('')
# axins.set_yticklabels('')
axins.set_xlabel(None)
axins.set_ylabel(None)
axins.plot(x, y, color="k", linewidth=1.5)
axins.hlines(y=beta*c, xmin=beta, xmax = 10, color="k", linewidth=1.5)
axins.vlines(x=beta, ymin=beta*c, ymax = 15, color="k", linewidth=1.5)
# ax[0].indicate_inset_zoom(axins)
mark_inset(ax[0], axins, loc1=2, loc2=4, fc="none", ec="0.5",edgecolor="black")


#################################### Subfig2  ###########################################

import matplotlib.pyplot as plt
import numpy as np

url1='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/te_ana_heatmap1_aw_final_length_10.txt'
df_heatmap = pd.read_csv(url1,sep = ',', header=None)

url2='/content/drive/MyDrive/Colab Notebooks/Heatmap_realistic_rates/Figure_4_ecoli/te_ana_heatmap1_aw_final_subset_length_10.txt'
df_subset_heatmap = pd.read_csv(url2,sep = ',', header=None)

beta=30;
c=(1+np.sqrt(10));
x =np.linspace(0,beta,20)
y = c*x;
ax[1].set_yscale("log")
ax[1].set_xscale("log")
im=ax[1].pcolormesh(alpha_rates,omega_rates,df_heatmap,cmap ='YlGnBu', alpha=0.5)
fig.colorbar(im)
ax[1].plot(x, y, color="k", linewidth=1.5)
ax[1].hlines(y=beta*c, xmin=beta, xmax = 60, color="k", linewidth=1.5)
ax[1].vlines(x=beta, ymin=beta*c, ymax = 200, color="k", linewidth=1.5)

sns.scatterplot(data=df_wild, x="a", y="w", hue="exp_level", palette="dark:#5A9_r",ax=ax[1])

ax[1].set_xlabel(r'$ \mathrm{\alpha\hspace{.4}(s^{-1})} $')
ax[1].set_ylabel(r'$ \mathrm{\omega\hspace{.4}(s^{-1})} $')
ax[1].set_title('Flux (te)')
ax[1].legend(title="Expression level", loc="upper left", bbox_to_anchor=(1.52, 0.39))   # moves legend out of plot to some position
fig.subplots_adjust(hspace=0.3)   #  Adjust the spacing between subplots

# Create an inset axis
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset

# # Define the extent for the image (x-axis min, x-axis max, y-axis min, y-axis max)
# extent = (0, 60, 0, 200)

# loc=[0.5 0.5, 0.47, 0.47]"upper right"width="40%", height="40%",

# Create the inset axis

#axins1=inset_axes(ax[1], width="40%", height="40%", loc="upper left")
inset_pos = [1.3, 0.4, 0.6, 0.6]  # [x, y, width, height]
# axins1=inset_axes(ax[1], width="40%", height="40%", bbox_to_anchor=inset_pos)
axins1 = inset_axes(ax[1], width="70%", height="70%", loc='upper left', bbox_to_anchor=inset_pos, bbox_transform=ax[1].transAxes)

# axins = inset_axes(ax[1],  width="10%", height="10%", bbox_to_anchor=(1,0.2, 0.47, 0.17), bbox_transform=ax[1].transAxes)


# Plot the zoomed-in region in the inset axis
axins1.set_yscale("log")
axins1.set_xscale("log")
axins1.pcolormesh(alpha_rates1, omega_rates1, df_subset_heatmap, cmap ='YlGnBu', alpha=0.5)
cbaxes = inset_axes(axins1, width="5%", height="100%", loc='upper right', bbox_to_anchor=(0.15, 0.036, 1 ,1), bbox_transform=axins1.transAxes) # width,height% of colorbar,bbox=(x,y,width,height)
cbar = plt.colorbar(axins1.collections[0], cax=cbaxes, format="%.1f")

sns.scatterplot(data=df_wild,  x="a", y="w", hue='exp_level', palette='dark:#5A9_r', ax=axins1, legend=False)

# axins1.set_xticklabels(['0.1', '1', '10'])

x1, x2, y1, y2 = 0.05, 10, 5.6, 15

axins1.set_xlim(x1, x2)
axins1.set_ylim(y1, y2)
# axins1.set_yticklabels([10])
# axins1.set_yticks([10])
axins1.set_xlabel(None)
axins1.set_ylabel(None)
axins1.plot(x, y, color="k", linewidth=1.5)
axins1.hlines(y=beta*c, xmin=beta, xmax = 10, color="k", linewidth=1.5)
axins1.vlines(x=beta, ymin=beta*c, ymax = 15, color="k", linewidth=1.5)
#  Add the lines to indicate where the inset axis is coming from

mark_inset(ax[1], axins1, loc1=2, loc2=4, fc="none", ec="0.5", edgecolor="black")

# # axis.indicate_inset_zoom(axin)
# ax[1].indicate_inset_zoom(axins)

plt.show()

fig.savefig("FIG_3.jpg", transparent=True, bbox_inches='tight', pad_inches=0,dpi=1000 )

from google.colab import files

files.download('/content/FIG_3.jpg')
# Out:
# /tmp/ipykernel_680/3919889807.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_wild = pd.read_csv(url2,delim_whitespace=True)
